# %% [markdown]
# DT Classifier
#
# DT Regresser
#
# entropy - purity(0), impurity(>0)
#
# imbalanced data set - yes more, no less values or vice versa
#
# decision tree tries to find entropy 0(leaf note has 0 entropy, root e >1).
#
# As we move down to leaf, e reduces
#
# max_depth

# %% [markdown]
# ## Decision Tree - Intro and Geometric Intuition
# https://www.youtube.com/watch?v=gwgmSSTdiXs&list=PLKnIA16_RmvYGY_n9PP8zN-0LG9MoZRjU
# - DT is also called as Classification and Regression Trees - Reason >>> DT is used mostly for classiciation, but in some cases we can use for Regression problems as well.
# - DT Can work both with categorical and numerical variables.
# - DT are a gaint set of nested if-else condition.
# - In 3D Co-ordinate system, a line is called as plane. So a decision tree uses hyperplanes which run parallel to any one of the axes to cut your co-ordinate system intp hyper cuboids - Check "Geometric intuition of above data" diagram below.

# %% [markdown]
# Example1:-
#
# ![image.png](attachment:f0a1468e-5ef1-41b1-aae7-4e2800258ff5.png)
#
# ![image.png](attachment:79bb341a-3ccf-4b6b-b806-81b5c2e821cd.png)

# %% [markdown]
# Example2:-
#
# ![image.png](attachment:bda42b89-6fa2-43aa-b012-8892f9c77253.png)
#
# - .
# - If input query is [ Rainy, Mild, High, Strong ]
# - First checkes for Outlook = Rainy >>> Goes directly to Humidity = High, by skipping Temp >>> Play = No, it doesn't even check for Wind.
# - This is how a decision tree is build, it need not check all the conditions, it all depends on how good a decision tree is being built.

# %% [markdown]
# ## What if the input data is numerical?

# %% [markdown]
# ![image.png](attachment:04dac9c5-65d5-4a40-bf59-c673e74943b7.png)

# %% [markdown]
# #### Geometric intuition of above data.
# - .
# - ![image.png](attachment:38b17f05-312d-49a1-a3c6-2d13eac9997a.png)

# %% [markdown]
# ### Terminology
# ![image.png](attachment:a2edee2e-05fa-4776-9fb0-85ff2ddcb461.png)

# %% [markdown]
# ### Steps for Decision Tree
# - Assuming dataset has feature variables(Input Columns) and Classification Or Regression Output.
# - Determine the "Best Input Feature" in the dataset using which we can split the data on >>> How to determine the best feature - discussed later.
# - Split the data into subsets that contain correct values for this best feature. This splitting basically defines a node on the tree i.e. each node is a splitting point based on a certain feature from our data.
# - Recursively generate new tree nodes by using the subset of data created from step3
#
# #### Questions
# - How to determine the best feature to split the data initially i.e. how to decide a root node.
# - How to select subsequent decision nodes.
# - How to decide splitting criteria in case of numerical columns.
# All these questions will be answered below.

# %% [markdown]
# ### Advantages and Disadvantages
#
# ![image.png](attachment:fd5d7bdb-ce6e-41b2-9acd-10c435cbbe3f.png)
