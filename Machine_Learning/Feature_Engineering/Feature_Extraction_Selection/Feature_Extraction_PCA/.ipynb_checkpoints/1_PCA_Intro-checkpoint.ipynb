# %% [markdown]
# https://www.youtube.com/watch?v=iRbsBi5W0-c
#
# - Alternative to PCA is DBScan - new technique instead of PCA, PCA is old, but DBSCAN is gaining popularity

# %% [markdown]
# ### Principal Component Analysis - PCA
# - Reduces the number of features and process time. And also useful for visualization.
# - This is most commonly used feature extraction technique to reduce the curse of dimensionality for feature extraction.
# - This is a Unsupervised machine learning problem, uses complex mathemetics for feature extraction.
# - PCA is a technique that reduces the data from higher dimensionality to lower dimensionality
# - Advantages of using PCA:-
# - - The number of columns reduces - Increases the faster execution of algorithms and less computation.
# - - Visualization - reduces the features to 2D/3D which can be plotted and visualize.
#   - PCA works well if we do scaling with Standarrd scaler

# %% [markdown]
# ### Feature selection VS Feature extraction
# - <b>Feature selection</b> - Just select most important features that you think has significant impact on the outcome. But to prove this mathematically, we consider spread/variance.
# - - Mathematically to prove the above
#   - Take the spread/variance - the column that is spread more on the axis - which means that column is more say in deciding the outcome.
#   - In below example, we take rooms column as it has more spread.
#   - Feature selection is used when the spread of the features is different for different columns i.e. variance is different for different features, by just taking the feature that has more spread/variance..
#   - ![image.png](attachment:9478e5b3-4760-42e3-a775-2b413d6bd66c.png)
# - .
# - <b>Feature extraction</b> - Algorithm reduces the features by creating new features. This is used when the spread of feature is almost same for all the features, which means there is a linear relationship between features, i.e. variance/spread is almost same for all features.
# - In this case we cannot pick one column as both have the same variance/spread.
# - ![image.png](attachment:7798740d-cf22-4b34-aa33-1251f815e4ca.png)
# - In this case we use feature extraction.

# %% [markdown]
# ### How does PCA Work
# - In above example, if we are unable to pick between number of rooms and number of washrooms, then derive a new column with the size of the flat by multiplying the size of rooms and washrooms, this creates a totally new column and then considers that in the model instead of taking no of rooms and number of washrooms features.
# - PCA creates new features from the existing set of features and decides which new features have to be used in the model.

# %% [markdown]
# ### Mathematical Intution / Geometric Intution behind PCA

# %% [markdown]
# - In the above example, PCA changes the axis, such that the variance of one feature is different from the variance of the other feature and then comes with new features.
# - In this case, the No Of rooms axis is changed to rooms' and washrooms axis is changed to wrooms', because of this change, we can see the variance (d) of rooms' is greater than the variance (d') of wrooms', then these two new features are called as PCA1(rooms') and PCA2(wrooms'). PCA algorithm will choose PCA1(rooms') feature for the model building.
# - .
# - ![image.png](attachment:bde4c753-e3a2-45dd-9b3c-7e996326bcbf.png)
# - .
# - Note:- Always the number of new features i.e. principal components (PCA1, PCA2, etc.) are <= to the number of original features.

# %% [markdown]
# ### Importance of Variance in PCA
# - Mean - Sum of values / No of values.
# - Mean is used to identify the central tendancy i.e. to detect the central point. Not to find the difference between two datasets.
# - - Problem with Mean:- The Mean of below two datasets is same, so we cannot differentiate the two datasets.
#   - ![image.png](attachment:21bedb6f-d505-4258-8ef9-03cefa000b66.png)
# - .
# - Variance:- Is used to identify how much each value in a dataset is far from the mean value of the data set. This will help in clearly identifying the axis where the differences are clearly seen between the datapoints.
# - .
# - ![image.png](attachment:a697b95a-82d4-41e9-b7bd-7f0b17609099.png)
# - .
# - For the above example, we can see the variance is different
# - Variance of first dataset:- (25+0+25)/3 = 50/3 = 16.6
# - Variance of second dataset:- (100+0+100)/3 = 200/3 = 66.66
# - We can clearly see the variance of dataset2 > variance of dataset1, which helps us to choose dataset2 over dataset1 for PCA i.e. for model creation use dataset2 as the spread of more.
# - Note: Spread is not same as Variance, but spread is directly proprotional to variance. i.e. when the spread of the data is more, the variance will be more.
# - .
# - One more example depicting the importance of Spread.
# - Let us take two points (Red and Green), if we project them on x and y axis, we can clearly see the axis that has more spread (x axis in this case) is truly depicting the distance between Red and Green, whereas the y axis is not truly depciting the distance between Red and Green. Since x axis projection has more spread(more Variance).
# - This is why we take the axis with more spread, as it rightly projects the distance between the two points as they are in the original axis.
# - This is why PCA uses variance to change the dataset from higher dimension to lower dimension.
# - ![image.png](attachment:84844482-28ff-47a3-b74a-7ac4dbf736d4.png)

# %% [markdown]
# ### How PCA Projects the datapoints on a new line (Vector)
# - In order to project the datapoints on a new vector, PCA uses dot product on a unit vector.
# - Unit Vector:- A vector (Axis) without magniture(length), just the direction.
# - Select any random unit vector(u') and try plotting all the datapoints on this vector using dot product.
# - Ex: To project vector Red (from above diagram) on another vector, new projection = newVector. OldVector / magnitude of new vector.
# - ![image.png](attachment:a77c646f-d6e2-4887-83ad-6440c96e3131.png)
# - Finally the new vector value becomes a scaler(number).
# - Similarly we plot all the points on the unit vector, we get multiple points on new vector.
# - Our goal is to find a vector where the Variance (or spread) is maximum after plotting the new points on the vector using dot product.
# - Steps:-
# - - Draw a random vector
#   - Project the data points on the new vector using dot product. UtXi >>> (cordinates of U)Transpose * Coordinates of new unit vector.
#   - Calculate the Variance, where mean = mean of the existing dataset
#   - ![image.png](attachment:ed95a008-32be-463e-aeaa-9257bf31136c.png)
#   - Similarly, draw the other vectors and plot the points
#   - After drawing all the unit vectors & deriving their mean, select the vector that has maximum variance.
#   - ![image.png](attachment:39b1fb57-a045-42ea-8888-da525db596c1.png)

# %% [markdown]
# ### CoVariance & CoVariance Matrix
# - Covariance measures the direction of the relationship between two variables.
# - A positive covariance means that both variables tend to be high or low at the same time.
# - A negative covariance means that when one variable is high, the other tends to be low.
# - CoVar(x,y) = Σ (X - μ of x)(Y - μ of y)/N
# - +ve - both increase in the same direction.
# - -ve - both in different directions.
# - ![image.png](attachment:0ff5a4f5-9907-4395-bada-2c2ece05f9a6.png)
# - .
# - CoVariance Matrix in case of 2D (x,y):-
# - ![image.png](attachment:228596e6-e23c-427b-9592-4f4fbd7d259a.png)
# - .
# - Significance of CoVariance Matrix
# - The diagnoal axis in the covariance matrix tells how the data is spread on all the axis.
# - The other items tells what is the orientation of the data i.e. how each axis is related to the other axis. (CoVariance)
# - It also tells the relationship between the two axis in +ve or -ve direction.
# - .
# - CoVariance Matrix in case of 3D (x,y,z):-
# - .
# - ![image.png](attachment:8fc79952-860d-4a2e-8239-f3cd35d32882.png)

# %% [markdown]
# ### Matrix Linear Transformation
# - Trasform a vector using a Matrix
# - Let us take a point(Unit vector) on 2D, for Ex: (2,3)
# - Use a 2*2 matrix (Ex below) to transform the data point to other dimension, using the dot product
# - Ex: [3 0
# -      1 2]
# -
# - For matrix transformation, if both the matrixes size is not same, we need to transpose.
# - In this case size of the data point (2,3) is 1*2 and our matrix size is 2*2, since x1,y1 and x2,y2, y1 and x2 size is same, we can do dot product without transpose.
# - So dot product of 1*2 and 2*2 will be 1*2
# - [2 3] * [3 0
# -          1 2] = [2*3 + 3*0   2*1 + 3*2] = [6  8]
# - .
# - Example2:- Matrix transformation of 3D coordinate
# - [5
# - 6
# - 2] with a matrix 2*3, result will be as shown below.
# - .
# - ![image.png](attachment:fd269f58-afb8-490a-8010-6d5140c53a53.png)
# ## Eigen Vectors and Eigen Values
# - Eigen vector is a vector, even after applying the matrix transformation, the direction is not changed. Magnitue can change.
# - The values of a matrix using which when we do dot product, the direction of the unit vector does not change, these vectors are called as Eigen vectors and the dot product values (enhanced or reduced values of the dot product on new vector) are called as Eigen values.
# - Example3:- with website -
# - ![image.png](attachment:7180ad6c-4e47-4ce0-8c3a-6e37f7b37b6a.png)
# - In this example, a unit vecot (A datapoint) [-1,1] is transformed to [-2,0] using the matrix
# - [2 0
# -  1 1]
# -  Calculation:- [-1*2+1*0   -1*1+1*1] = [-2 0]
# -  We can see the direction and the magnitue of the new vector has changed. hence this is <b>not a eigen vector.
# -  .
# -  Example4:-
# -  ![image.png](attachment:2a918426-b973-4080-b2e4-269ac4c4a98c.png)
# - In this example, a unit vecot (A datapoint) [-1,1] is transformed to [-2,2] using the matrix
# - [3 1
# -  0 2]
# -  Calculation:- [-1*3+1*1 -1*0+1*2] = [-2 2]
# -  We can see the direction has not changed. hence this is <b> a eigen vector.

# %% [markdown]
# ### Eigen Decomposition of CoVariance Matrix
# - When we apply matrices as a linear transformation, all the vectors (data points) are transformed to a new vectors.
# - But, there will be 2 vectors in 2D space, which doesnt change the direction, these are called as Eigen vectors.
# - Similarly, in 3D space, we get 3 eigen vectors, and so on.
# - The corrosponding increased or decreased co-ordinates are called as Eigen values.
# - Eigenvalue Equation:
# - The eigenvalue equation is: Av = λv, where:
# - A: is the square matrix.
# - v: is the eigenvector (a non-zero vector that doesn't change direction when multiplied by A).
# - λ: (lambda) is the eigenvalue.
# ### How Eigen vectors/values are used by PCA
# - Use CoVariance Matrix of the dataset, instead of a normal random matrix for the Linear transformation, we get N number of Eigen vectors based on the dimension of the data.
# - Pick the largest Eigen vector among all the eigen vectors, this eigen vector will always point to the direction of largest variance of the data. The magnitude of this Eigen vector will be the corrosponding Eigen value.

# %% [markdown]
# # Step wise derivation of Principal Components.
# - Steps:-
# - 1. Get the mean center of the data i.e. perform Standard Scaling of all the features.
#   2. Derive CoVariance matrix.
#   3. Get the Eigen Vectors & Values
#   4. Choose those vectors/PC from the largest one as their variance will be more. Choosing PC 1 or 2 or more depends upon how much weightage each PC is giving us.
# - Note:- The largest Eigen Vector will be the unit vector which has maximum spread/Variance. This is also called as Principal Component 1 (PC1)
# - The second largest Eigen Vector will be called as PC2, and so on.
# - .
# - Step1:- Standard Scaling - Mean center, below pic shows the 2D data.
# - ![image.png](attachment:db71719a-638f-4b05-951d-86e4612127b2.png)
# - .
# - Step2:- Derive CoVariance Matrix, below pic shows for 3D data.
# - ![image.png](attachment:6a2dd5f9-92e0-4f37-86d1-c203fad72a7b.png)
# - .
# - Step3:- Find the Eigen Values/Vectors for the above 3D CoVariance matrix. Since this is 3D, we get 3 Eigen Vectors.
# - ![image.png](attachment:11e82581-ed19-41bd-82ab-c2c0f541c757.png)
# - ![image.png](attachment:24d47831-8c32-4dc1-8493-f4fdfb5c948d.png)
# - From above pic, we can see, 3 Eigen vectors are derived, here Eigen Vector1 is largest, hence this will be PC1, and so on.
# - Step4:- Based on the weightage of the Principal Components, take either 1 or 2 or more PCs and transform the data.
# - Ex: If we had 10 features, and once we apply PCA, we get 10 PCAs, so its up to us to take only 1 PCA or 2 or more and transform the data and train the model.
# - Ste5:- Transform the input features using the Eigen vectors. If we have 10 features and we decided to change to 3D, it means take 3 Eigen vectors and perform dot product of all the input features with the 3 Eigen vectors(Transpose eigen vectors if required to perform dot product)

# %% [markdown]
# #### Example - How to transform points
# - Ex: 3D to 1D
# - If we have a 3D dataset & we want to transform to only 1D.
# - feature1 | feature2 | feature3 | Target > shape (1000,4) >>> Change to 1D i.e. take only PC1 >>> PC1 | Target > Shape (1000,2), assuming 1000 rows.
# - To transform 3D data to one unit vector, use dot product. i.e. data shape is (1000,3) and unit vector shape is (1,3)
# - First transpose unit vector from (1,3) to (3,1) to perform dot product, it both needs to be of same size.
# - ![image.png](attachment:fd69f871-bffa-4d38-8ba0-9ee39d39aaf8.png)
# - In above pic, we get PC1 (1000,1)
# - Since we wanted only 1D, we used only one unit vector.
# - .
# - Ex: 3D to 2D
# - ![image.png](attachment:d05d8ebb-e404-477a-87e9-e2b734f8877f.png)
# - In above pic, we get the PC1 & PC2 (1000,2)
# - Since we wanted 2D, we used two unit vectors.
# - Once we finalize the number of Eigen Vectors, take all the input features and perform the dot product with the selected number of Eigen Vectors(Transpose if required)

# %% [markdown]
# ### Scenarios where PCA cannot be applied.
# - Even after project, in below scenarios we cannot differentiate one PC with the other.
# - ![image.png](attachment:89b0035d-3e9e-427b-a29e-ec9e406e66fb.png)
