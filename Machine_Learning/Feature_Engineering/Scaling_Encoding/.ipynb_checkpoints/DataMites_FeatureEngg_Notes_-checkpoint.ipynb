# %% [markdown]
# # What is Feature Scaling?

# %% [markdown]
# ### Feature Scaling is a technique to standardize the independent feature present in the data in a fixed range.

# %% [markdown]
# ![Why Feature Scaling is important](image-1.png)

# %% [markdown]
# ![Why Feature Scaling is important](image-2.png)

# %% [markdown]
# # Standardization

# %% [markdown]
# #### Standardization, also known as Z-score normalization, is a feature scaling technique that transforms data to have a mean of 0 and a standard deviation of 1

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Social_Network_Ads.csv')

# %%
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df1 = df.iloc[:,2:]

# %%
df1.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
x = df1.drop('Purchased',axis=1)
y = df1['Purchased']

# %%
x
# Out:
#      Age  EstimatedSalary
# 0     19            19000
# 1     35            20000
# 2     26            43000
# 3     27            57000
# 4     19            76000
# ..   ...              ...
# 395   46            41000
# 396   51            23000
# 397   50            20000
# 398   36            33000
# 399   49            36000
#
# [400 rows x 2 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    0
# 399    1
# Name: Purchased, Length: 400, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# %%
# X_train.shape

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
x_train_scaled = scaler.transform(X_train)
x_test_scaled = scaler.transform(X_test)

# %%
x_train_scaled
# Out:
# array([[-1.06675246, -0.38634438],
#        [ 0.79753468, -1.22993871],
#        [ 0.11069205,  1.853544  ],
#        [ 0.60129393, -0.90995465],
#        [ 1.87685881, -1.28811763],
#        [-0.57615058,  1.44629156],
#        [ 0.3069328 , -0.53179168],
#        [ 0.99377543,  0.10817643],
#        [-1.16487283,  0.45724994],
#        [-1.55735433,  0.31180264],
#        [ 1.0918958 ,  0.45724994],
#        [-0.18366908, -0.47361276],
#        [ 0.20881242, -0.32816546],
#        [ 0.3069328 ,  0.28271318],
#        [-1.16487283, -1.57901222],
#        [ 0.11069205,  0.25362372],
#        [ 2.07309956,  1.73718616],
#        [ 0.40505317, -0.18271817],
#        [ 1.4843773 ,  2.11534913],
#        [-0.37990983,  1.21357589],
#        [ 1.87685881,  1.50447048],
#        [ 0.11069205,  0.02090805],
#        [ 0.89565505, -1.31720709],
#        [-1.36111358, -1.49174384],
#        [-0.18366908, -0.5899706 ],
#        [-0.57615058,  2.31897535],
#        [ 0.99377543, -1.20084925],
# ...

# %%
scaler.mean_
# Out:
# array([3.7871875e+01, 7.0281250e+04])

# %%
X_train
# Out:
#      Age  EstimatedSalary
# 3     27            57000
# 18    46            28000
# 202   39           134000
# 250   44            39000
# 274   57            26000
# ..   ...              ...
# 71    24            27000
# 106   26            35000
# 270   43           133000
# 348   39            77000
# 102   32            86000
#
# [320 rows x 2 columns]

# %%
# x_train_scaled

# %%
x_train_scaled = pd.DataFrame(x_train_scaled, columns = X_train.columns)
x_test_scaled = pd.DataFrame(x_test_scaled, columns = X_test.columns)

# %%
x_train_scaled
# Out:
#           Age  EstimatedSalary
# 0   -1.066752        -0.386344
# 1    0.797535        -1.229939
# 2    0.110692         1.853544
# 3    0.601294        -0.909955
# 4    1.876859        -1.288118
# ..        ...              ...
# 315 -1.361114        -1.259028
# 316 -1.164873        -1.026312
# 317  0.503174         1.824455
# 318  0.110692         0.195445
# 319 -0.576151         0.457250
#
# [320 rows x 2 columns]

# %%
X_train.describe()
# Out:
#               Age  EstimatedSalary
# count  320.000000        320.00000
# mean    37.871875      70281.25000
# std     10.207525      34430.55286
# min     18.000000      15000.00000
# 25%     30.000000      43000.00000
# 50%     37.000000      71000.00000
# 75%     45.000000      88000.00000
# max     60.000000     150000.00000

# %%
np.round(x_train_scaled.describe(),1)
# Out:
#          Age  EstimatedSalary
# count  320.0            320.0
# mean    -0.0              0.0
# std      1.0              1.0
# min     -1.9             -1.6
# 25%     -0.8             -0.8
# 50%     -0.1              0.0
# 75%      0.7              0.5
# max      2.2              2.3

# %%
fig , (ax1,ax2) = plt.subplots(ncols=2, figsize=(12,5))

ax1.scatter(X_train['Age'],X_train['EstimatedSalary'])
ax1.set_title('Before Scaling')
ax2.scatter(x_train_scaled['Age'],x_train_scaled['EstimatedSalary'],color='green')
ax2.set_title('After Scaling')
# Out:
# Text(0.5, 1.0, 'After Scaling')

# %%
# from sklearn.linear_model import LogisticRegression

# %%
# model = LogisticRegression()

# %%
# model.fit(X_train,y_train)

# %%
# y_pred = model.predict(X_test)

# %%
# from sklearn.metrics import accuracy_score

# %%
# accuracy_score(y_test,y_pred)

# %%
# model2 = LogisticRegression()

# %%
# model2.fit(x_train_scaled,y_train)

# %%
# y_pred2 = model2.predict(x_test_scaled)

# %%
# accuracy_score(y_test,y_pred2)

# %% [markdown]
# # Normalization

# %% [markdown]
# ### Normalization is a technique often applied as part of data preparation for machine learning.The goal of normalization is to change the value of numeric columns in the dataset to use a common scale, without distorting differences in the range of values or losing information

# %% [markdown]
# #### MinMaxScaling

# %% [markdown]
# MinmaxScaler is a normalization technique that scales the data to a fixed range typically [0,1]. It linearly
# transforms features by shrinking them to fit within this range.

# %% [markdown]
# xi_new = xi - xmin / xmax - xmin

# %% [markdown]
# Sensitive to outliers

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# scaled = MinMaxScaler()

# %%
# scaled.fit_transform()

# %%
# Mean normalization --- xi - xmean / xmin - xmax (not in sklearn)

# %% [markdown]
# #### MaxAbs Scaling

# %% [markdown]
# MaxAbsScaler is a normalization technique that scales each feature by its maximun absolute value so that the resulting values are within the range [-1,1]

# %% [markdown]
# x_new = xi /|xmax|

# %%
# handles sparse data (zeros)

# %%
from sklearn.preprocessing import MaxAbsScaler

# %% [markdown]
# #### Robust Scaling

# %% [markdown]
# RobustScaler is a normalization technique that scales features using stastics that are robust to outliers. it uses the median and interquartile range (IQR) instead of mean and standard deviation.

# %% [markdown]
# x_new = x - median / IQR
