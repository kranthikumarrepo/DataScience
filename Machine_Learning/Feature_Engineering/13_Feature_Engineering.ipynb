# %% [markdown]
# #### Feature Engineering
# - 1. Handling missing values - Imputation
# - 2. Feature Scaling
# - 3. Outlier detection
# - 4. Handling categorical columns - Feature Encoding
# - 5. Feature Selection

# %% [markdown]
# ![image.png](attachment:06940e86-0432-4423-a41e-a9e298dc7473.png)
