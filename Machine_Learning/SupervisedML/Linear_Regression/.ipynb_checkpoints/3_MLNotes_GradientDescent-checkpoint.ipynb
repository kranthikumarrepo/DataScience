# %% [markdown]
# ### Gradient Descent
# - is an algorithm that finds the best fit line for given training data set.
# - This is not a cost function, but just an algorithm to find the best fit line in less iterations.
# - Gradient descent is not a loss function. It is an optimization algorithm used to find the parameters that minimize a loss function.
# - The loss function quantifies how well a model's predictions match the actual values, and gradient descent iteratively adjusts the model's parameters to reduce this loss.
# - We use the cost function (MAE) to find the cost inside gradient descent.
# - Gradient decent is used in background by algorithms.

# %% [markdown]
# Types of Gradient Descent
#
# The main types of gradient descent are Batch Gradient Descent, Stochastic Gradient Descent, and Mini-batch Gradient Descent, each differing in how they use training data to update model parameters.
#
# Batch Gradient Descent uses the entire dataset
#
# Stochastic Gradient Descent uses a single data point
#
# Mini-batch Gradient Descent uses a small subset (a batch) of the data.
#
# Here's a breakdown of each:
#
# Batch Gradient Descent: This method calculates the error for every data point in the entire training set and updates the model's parameters based on the average error.
# It's computationally expensive for large datasets but tends to converge to a minimum more reliably.
#
# Stochastic Gradient Descent (SGD): In contrast, SGD uses only one randomly selected data point to compute the error and update the parameters in each iteration. It's faster than batch gradient descent but can be more erratic and fluctuate around the minimum.
#
# Mini-batch Gradient Descent: This is a compromise between the two, using a small random subset of the training data (a mini-batch) to calculate the error and update parameters. It offers a balance between speed and stability, making it a popular choice.
#
# Other important concepts related to gradient descent:
# Learning Rate:
# A crucial hyperparameter that determines the step size during parameter updates. Choosing an appropriate learning rate is essential for effective convergence.
#
# Momentum:
# A technique that adds a momentum term to the gradient update, accelerating convergence and helping to escape local minima.
#
# Local Minima:
# Cost functions can have multiple local minima, and gradient descent can sometimes get stuck in one of these rather than finding the global minimum.
#
# Exploding and Vanishing Gradients:
# These are problems that can occur during the training of deep neural networks, where gradients become too large or too small, respectively, hindering learning

# %% [markdown]
# - Instead of drawing different permutations and combinations of linear line (m and b)
# - In less iterations, find the best fit line by determinig m and b
# - We use Mean Square Error (MSE), for every value of m and b, we find the cost.
# - .
# - Steps:-
# - .
# - Start with m(Slope) = 0 and b(Y Intercept) = 0 (Or) Start with some random value of m(Slope) and b(Y Intercept).
# - Iterate the below steps, n number of times(EPOCHS). Ex EPOCHS = 100, iterate 100 times. Untill the best cost/lowest value for b and c are found.
# - .
# - Find the value of y, i.e. predict the value using y = mx + b. We already have values for m and b.
# -
# - Reduce/Increase the value of m and b by learning curver(Ex: 0.01) and find the new slope and intercept.
# ![image.png](attachment:ea7aa840-65ee-4ec9-9fe2-bc0c74c5306f.png)
# - Remember to keep the learning curve as small as possible, otherwise we might miss the minimum point as shown in below diagram
# ![image.png](attachment:2acbc51d-99dd-4d4a-8f6b-cee6922181dc.png)
# - Keep reducing the value of m and b untill the error(Cost) is minimum Or loss is < 0.0001 Or Go untill the slope becomes constant(Cost new = Cost old)
# ![image.png](attachment:a3a50958-cf03-4cd8-8a4a-f4d76d5905c5.png)
# - Find the next point(slope) by using the formula. At each point, we need to calculate the slope at a particular point and identify the next slope.
# Slope(m) between two points = Change in Y / Change in X = Delta Y / Delta X
# ![image.png](attachment:985fedac-746d-43e2-89a9-1c0984d5170e.png)
#
# Slope(m) at a particular point(Small change in Y and X)
# X Changes from x to x + Delta x
# Y Changes from f(x) to f(x+Delta x)
#
# Now if we put the above values in the slope formula
# = change in Y/Change in X = (f(x + Delta x) - f(x))/ Delta x
# Simplify it as best as we can, make delta x shrink towards 0
# If we simply further the Delta X heads towards zero, we get 2x,
# in other words, the slope at x is 2x
# So when x=2, slope = 4
# when x=5, slope = 10
#
# - Derivate of functions that depends on two variables is
#
# f(x,y) = x power 3 + y power 2
#
# partial derivate of x = 3 * x power2
#
# partial derivate of y = 2 * y
#
# ![image.png](attachment:2b45bb70-a750-4ba1-962c-8117678efb95.png)
#
# Now if we put this partial derivate in MSE, so this finally gives us the required slope.
#
# ![image.png](attachment:45b3ead8-95f0-4b55-840f-6975eb260eea.png)
#
# - Iterate this process n number of times(EPOCHS). Ex EPOCHS = 100, iterate 100 times >>> hyper parameter tuning  - gives understanding of how epochs and learning rate
# - Steps and learning rate. Now since we know the initial value of slope, and we decided the learning rate, calculate the next slope.
#
# ![image.png](attachment:e74772fb-f46f-42e0-8254-9d6d1c5f85f6.png)
#
# Example to calculate the next slope:-
#
# ![image.png](attachment:b8a43355-6012-4bde-b8ba-22a7f2fa0191.png)
#
# since we started with b1, to calculate the next slope
#
# b2 = b1 - learning rate * derivate

# %% [markdown]
# #### Implement Gradient Descent in Python

# %%
import numpy as np

def gradient_descent(x,y):

    # Start by taking slope and intercept as 0
    m_slope_curr = b_intercept_curr = 0

    # Start with 1000 iterations and fine tune it later
    iterations = 10000

    # Fix the learning rate
    learning_rate = 0.25

    # Length of data points i.e. number of data points.
    n = len(x)
    
    # Iterate the calculations n number of times, until the cost is less, with min slope.
    for i in range(iterations):
        # Predict the new value
        y_predict = m_slope_curr * x + b_intercept_curr

        # Calculate the cost, Mean Square Error MSE
        cost = 1/n * sum([val**2 for val in (y - y_predict)])

        # Derivates of m and b
        m_derivate = -(2/n)*sum(x*(y-y_predict))
        b_derivate = -(2/n)*sum(y-y_predict)

        # Make the next m and b as per formula
        m_slope_curr = m_slope_curr - learning_rate * m_derivate
        b_intercept_curr = b_intercept_curr - learning_rate * b_derivate

        # Print the values of m, b and iternation number
        print("m_Curr_Slope = {}, b_Curr_Intercept = {}, Curr_Iteration_No = {}, Cost = {} ".format(m_slope_curr,b_intercept_curr,i,cost))

x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])

gradient_descent(x,y)
# Out:
# m_Curr_Slope = 15.5, b_Curr_Intercept = 4.5, Curr_Iteration_No = 0, Cost = 89.0
# m_Curr_Slope = -61.0, b_Curr_Intercept = -16.5, Curr_Iteration_No = 1, Cost = 2128.5
# m_Curr_Slope = 314.75, b_Curr_Intercept = 87.75, Curr_Iteration_No = 2, Cost = 51410.25
# m_Curr_Slope = -1532.5, b_Curr_Intercept = -423.75, Curr_Iteration_No = 3, Cost = 1242154.125
# m_Curr_Slope = 7547.375, b_Curr_Intercept = 2091.375, Curr_Iteration_No = 4, Cost = 30012795.5625
# m_Curr_Slope = -37084.75, b_Curr_Intercept = -10270.875, Curr_Iteration_No = 5, Cost = 725166268.03125
# m_Curr_Slope = 182303.1875, b_Curr_Intercept = 50496.1875, Curr_Iteration_No = 6, Cost = 17521397590.640625
# m_Curr_Slope = -896093.125, b_Curr_Intercept = -248202.1875, Curr_Iteration_No = 7, Cost = 423350322838.3828
# m_Curr_Slope = 4404737.84375, b_Curr_Intercept = 1220043.09375, Curr_Iteration_No = 8, Cost = 10228949769749.098
# m_Curr_Slope = -21651369.4375, b_Curr_Intercept = -5997080.71875, Curr_Iteration_No = 9, Cost = 247150900206250.22
# m_Curr_Slope = 106426799.046875, b_Curr_Intercept = 29478518.296875, Curr_Iteration_No = 10, Cost = 5971636272318836.0
# m_Curr_Slope = -523138357.65625, b_Curr_Intercept = -144900934.921875, Curr_Iteration_No = 11, Cost = 1.442861010787943e+17
# m_Curr_Slope = 2571474027.3359375, b_Curr_Intercept = 712257073.5234375, Curr_Iteration_No = 12, Cost = 3.486226892455402e+18
# m_Curr_Slope = -12640018717.796875, b_Curr_Intercept = -3501082499.7421875, Curr_Iteration_No = 13, Cost = 8.423387876453946e+19
# m_Curr_Slope = 62131707995.19922, b_Curr_Intercept = 17209486831.32422, Curr_Iteration_No = 14, Cost = 2.0352508745412646e+21
# m_Curr_Slope = -305406916209.8828, b_Curr_Intercept = -84592818572.63672, Curr_Iteration_No = 15, Cost = 4.917553581854969e+22
# m_Curr_Slope = 1501220350818.9277, b_Curr_Intercept = 415813965033.00586, Curr_Iteration_No = 16, Cost = 1.1881745652542817e+24
# m_Curr_Slope = -7379212526219.184, b_Curr_Intercept = -2043923543707.3887, Curr_Iteration_No = 17, Cost = 2.870855953103141e+25
# m_Curr_Slope = 36272341683562.92, b_Curr_Intercept = 10046857017479.582, Curr_Iteration_No = 18, Cost = 6.936534533293862e+26
# m_Curr_Slope = -178295823102237.06, b_Curr_Intercept = -49385084016600.09, Curr_Iteration_No = 19, Cost = 1.675998800273128e+28
# m_Curr_Slope = 876408829984982.5, b_Curr_Intercept = 242751192645060.1, Curr_Iteration_No = 20, Cost = 4.04953217638362e+29
# m_Curr_Slope = -4307966523899996.5, b_Curr_Intercept = -1193237648654939.2, Curr_Iteration_No = 21, Cost = 9.784440683903744e+30
# m_Curr_Slope = 2.1175705830532412e+16, b_Curr_Intercept = 5865330961522531.0, Curr_Iteration_No = 22, Cost = 2.3641071444041684e+32
# m_Curr_Slope = -1.0408867267967963e+17, b_Curr_Intercept = -2.8830893265037348e+16, Curr_Iteration_No = 23, Cost = 5.712132937161371e+33
# m_Curr_Slope = 5.116453669561144e+17, b_Curr_Intercept = 1.4171756238700077e+17, Curr_Iteration_No = 24, Cost = 1.3801600646161588e+35
# m_Curr_Slope = -2.514980494883016e+18, b_Curr_Intercept = -6.966092692406712e+17, Curr_Iteration_No = 25, Cost = 3.334729469562879e+36
# m_Curr_Slope = 1.2362326130834577e+19, b_Curr_Intercept = 3.4241661077041884e+18, Curr_Iteration_No = 26, Cost = 8.057341260822425e+37
# m_Curr_Slope = -6.0766716750311875e+19, b_Curr_Intercept = -1.683140614239977e+19, Curr_Iteration_No = 27, Cost = 1.9468070434469574e+39
# m_Curr_Slope = 2.986973345900031e+20, b_Curr_Intercept = 8.273437205426792e+19, Curr_Iteration_No = 28, Cost = 4.703856448085739e+40
# m_Curr_Slope = -1.4682395637364157e+21, b_Curr_Intercept = -4.0667881585787064e+20, Curr_Iteration_No = 29, Cost = 1.1365412693916336e+42
# m_Curr_Slope = 7.217096260600678e+21, b_Curr_Intercept = 1.9990199376756883e+21, Curr_Iteration_No = 30, Cost = 2.746100080405348e+43
# m_Curr_Slope = -3.5475463079216588e+22, b_Curr_Intercept = -9.826134422063174e+21, Curr_Iteration_No = 31, Cost = 6.6351005939615664e+44
# m_Curr_Slope = 1.743787854895694e+23, b_Curr_Intercept = 4.830012740779329e+22, Curr_Iteration_No = 32, Cost = 1.6031666218621835e+46
# m_Curr_Slope = -8.571547258147522e+23, b_Curr_Intercept = -2.374181145304575e+23, Curr_Iteration_No = 33, Cost = 3.8735557676277376e+47
# m_Curr_Slope = 4.213323437962071e+24, b_Curr_Intercept = 1.1670230314568995e+24, Curr_Iteration_No = 34, Cost = 9.359248178142249e+48
# m_Curr_Slope = -2.071049001801467e+25, b_Curr_Intercept = -5.736473641214658e+24, Curr_Iteration_No = 35, Cost = 2.2613725402411004e+50
# m_Curr_Slope = 1.0180191554288803e+26, b_Curr_Intercept = 2.8197498206414683e+25, Curr_Iteration_No = 36, Cost = 5.4639065749953714e+51
# m_Curr_Slope = -5.004048672526182e+26, b_Curr_Intercept = -1.3860412421112474e+26, Curr_Iteration_No = 37, Cost = 1.3201838498089613e+53
# m_Curr_Slope = 2.4597280889534693e+27, b_Curr_Intercept = 6.813052387733651e+26, Curr_Iteration_No = 38, Cost = 3.1898155163787485e+54
# m_Curr_Slope = -1.209073425845066e+28, b_Curr_Intercept = -3.3489395140435217e+27, Curr_Iteration_No = 39, Cost = 7.707201561360556e+55
# m_Curr_Slope = 5.943171343409326e+28, b_Curr_Intercept = 1.646163163065423e+28, Curr_Iteration_No = 40, Cost = 1.8622066261334695e+57
# m_Curr_Slope = -2.92135157899401e+29, b_Curr_Intercept = -8.091675433581276e+28, Curr_Iteration_No = 41, Cost = 4.4994457337161237e+58
# m_Curr_Slope = 1.4359833420510238e+30, b_Curr_Intercept = 3.977443596811951e+29, Curr_Iteration_No = 42, Cost = 1.0871517492498281e+60
# m_Curr_Slope = -7.0585415787514e+30, b_Curr_Intercept = -1.9551028332359384e+30, Curr_Iteration_No = 43, Cost = 2.6267655970168195e+61
# m_Curr_Slope = 3.469609135423521e+31, b_Curr_Intercept = 9.610260951509132e+30, Curr_Iteration_No = 44, Cost = 6.346765763318959e+62
# m_Curr_Slope = -1.7054780252132217e+32, b_Curr_Intercept = -4.723900655559826e+31, Curr_Iteration_No = 45, Cost = 1.5334994374901493e+64
# m_Curr_Slope = 8.383236211793472e+32, b_Curr_Intercept = 2.3220220050418417e+32, Curr_Iteration_No = 46, Cost = 3.7052265870181645e+65
# m_Curr_Slope = -4.120759596063339e+33, b_Curr_Intercept = -1.1413843315169288e+33, Curr_Iteration_No = 47, Cost = 8.95253283145366e+66
# m_Curr_Slope = 2.0255494679560419e+34, b_Curr_Intercept = 5.610447228336546e+33, Curr_Iteration_No = 48, Cost = 2.163102369476297e+68
# m_Curr_Slope = -9.956539690052672e+34, b_Curr_Intercept = -2.7578018405172356e+34, Curr_Iteration_No = 49, Cost = 5.226467133853807e+69
# m_Curr_Slope = 4.894113136601288e+35, b_Curr_Intercept = 1.3555908614820392e+35, Curr_Iteration_No = 50, Cost = 1.2628139604815572e+71
# m_Curr_Slope = -2.4056895406928853e+36, b_Curr_Intercept = -6.663374274160913e+35, Curr_Iteration_No = 51, Cost = 3.051198941743353e+72
# m_Curr_Slope = 1.1825109074242122e+37, b_Curr_Intercept = 3.2753655973312823e+36, Curr_Iteration_No = 52, Cost = 7.372277527360867e+73
# m_Curr_Slope = -5.812603923008648e+37, b_Curr_Intercept = -1.6099980812697544e+37, Curr_Iteration_No = 53, Cost = 1.7812826032699145e+75
# m_Curr_Slope = 2.857171477544355e+38, b_Curr_Intercept = 7.913906843878095e+37, Curr_Iteration_No = 54, Cost = 4.30391788824573e+76
# m_Curr_Slope = -1.404435767553131e+39, b_Curr_Intercept = -3.890061874122628e+38, Curr_Iteration_No = 55, Cost = 1.0399084993452164e+78
# m_Curr_Slope = 6.903470235107483e+39, b_Curr_Intercept = 1.9121505576235654e+39, Curr_Iteration_No = 56, Cost = 2.5126169111260644e+79
# m_Curr_Slope = -3.393384189441902e+40, b_Curr_Intercept = -9.399130073849442e+39, Curr_Iteration_No = 57, Cost = 6.070960806697756e+80
# m_Curr_Slope = 1.668009836356598e+41, b_Curr_Intercept = 4.620119780470382e+40, Curr_Iteration_No = 58, Cost = 1.4668597092241361e+82
# m_Curr_Slope = -8.199062230675248e+41, b_Curr_Intercept = -2.2710087655113783e+41, Curr_Iteration_No = 59, Cost = 3.5442123167247123e+83
# m_Curr_Slope = 4.0302293186305685e+42, b_Curr_Intercept = 1.1163088963257183e+42, Curr_Iteration_No = 60, Cost = 8.563491700693892e+84
# m_Curr_Slope = -1.9810495278326133e+43, b_Curr_Intercept = -5.487189529782994e+42, Curr_Iteration_No = 61, Cost = 2.0691026257597978e+86
# m_Curr_Slope = 9.73780130471421e+43, b_Curr_Intercept = 2.6972148152597707e+43, Curr_Iteration_No = 62, Cost = 4.9993458574604425e+87
# m_Curr_Slope = -4.78659280941036e+44, b_Curr_Intercept = -1.3258094549441429e+44, Curr_Iteration_No = 63, Cost = 1.2079371361934747e+89
# m_Curr_Slope = 2.3528381824762833e+45, b_Curr_Intercept = 6.5169844866434685e+44, Curr_Iteration_No = 64, Cost = 2.918606086870113e+90
# m_Curr_Slope = -1.15653194941398e+46, b_Curr_Intercept = -3.203408049382251e+45, Curr_Iteration_No = 65, Cost = 7.051907947096104e+91
# m_Curr_Slope = 5.684904979770248e+46, b_Curr_Intercept = 1.5746275216518574e+46, Curr_Iteration_No = 66, Cost = 1.703875213514907e+93
# m_Curr_Slope = -2.7944013691443906e+47, b_Curr_Intercept = -7.740043708829444e+46, Curr_Iteration_No = 67, Cost = 4.1168868978585736e+94
# m_Curr_Slope = 1.3735812717474173e+48, b_Curr_Intercept = 3.804599868275114e+47, Curr_Iteration_No = 68, Cost = 9.947182513909664e+95
# m_Curr_Slope = -6.751805703104646e+48, b_Curr_Intercept = -1.8701419142073706e+48, Curr_Iteration_No = 69, Cost = 2.4034286687957798e+97
# m_Curr_Slope = 3.3188338535281964e+49, b_Curr_Intercept = 9.192637597553284e+48, Curr_Iteration_No = 70, Cost = 5.807141226082781e+98
# m_Curr_Slope = -1.6313647980509878e+50, b_Curr_Intercept = -4.518618900414631e+49, Curr_Iteration_No = 71, Cost = 1.4031158759775807e+100
# m_Curr_Slope = 8.018934426291641e+50, b_Curr_Intercept = 2.2211162520557502e+50, Curr_Iteration_No = 72, Cost = 3.390195080115776e+101
# m_Curr_Slope = -3.9416879296396016e+51, b_Curr_Intercept = -1.0917843513409588e+51, Curr_Iteration_No = 73, Cost = 8.191356735403984e+102
# m_Curr_Slope = 1.9375272210389643e+52, b_Curr_Intercept = 5.366639718788923e+51, Curr_Iteration_No = 74, Cost = 1.979187733478652e+104
# m_Curr_Slope = -9.523868452493678e+52, b_Curr_Intercept = -2.6379588456190007e+52, Curr_Iteration_No = 75, Cost = 4.782094359804697e+105
# m_Curr_Slope = 4.681434630465006e+53, b_Curr_Intercept = 1.296682325593102e+53, Curr_Iteration_No = 76, Cost = 1.1554450383482321e+107
# m_Curr_Slope = -2.3011479325482182e+54, b_Curr_Intercept = -6.373810782900958e+53, Curr_Iteration_No = 77, Cost = 2.7917751850845357e+108
# m_Curr_Slope = 1.1311237313902126e+55, b_Curr_Intercept = 3.13303135967728e+54, Curr_Iteration_No = 78, Cost = 6.745460342445823e+109
# m_Curr_Slope = -5.560011495207549e+55, b_Curr_Intercept = -1.5400340291014553e+55, Curr_Iteration_No = 79, Cost = 1.6298316381134942e+111
# m_Curr_Slope = 2.7330102772086157e+56, b_Curr_Intercept = 7.570000228260594e+55, Curr_Iteration_No = 80, Cost = 3.937983523349207e+112
# m_Curr_Slope = -1.3434046281677861e+57, b_Curr_Intercept = -3.7210154043998947e+56, Curr_Iteration_No = 81, Cost = 9.51491790165504e+113
# m_Curr_Slope = 6.603473137415022e+57, b_Curr_Intercept = 1.8290561720316843e+57, Curr_Iteration_No = 82, Cost = 2.2989853090659383e+115
# m_Curr_Slope = -3.245921337641513e+58, b_Curr_Intercept = -8.99068162010669e+57, Curr_Iteration_No = 83, Cost = 5.554786185156332e+116
# m_Curr_Slope = 1.5955248262402816e+59, b_Curr_Intercept = 4.419347925456937e+58, Curr_Iteration_No = 84, Cost = 1.3421420937804986e+118
# m_Curr_Slope = -7.8427639068998055e+59, b_Curr_Intercept = -2.1723198430875758e+59, Curr_Iteration_No = 85, Cost = 3.242870814201831e+119
# m_Curr_Slope = 3.8550917345680494e+60, b_Curr_Intercept = 1.0677985938805923e+60, Curr_Iteration_No = 86, Cost = 7.835393261514024e+120
# m_Curr_Slope = -1.8949610696377113e+61, b_Curr_Intercept = -5.248738304911779e+60, Curr_Iteration_No = 87, Cost = 1.893180181390919e+122
# m_Curr_Slope = 9.314635559106469e+61, b_Curr_Intercept = 2.580004689210978e+61, Curr_Iteration_No = 88, Cost = 4.5742837399316403e+123
# m_Curr_Slope = -4.578586704979558e+62, b_Curr_Intercept = -1.2681950994054215e+62, Curr_Iteration_No = 89, Cost = 1.1052340363097443e+125
# m_Curr_Slope = 2.2505932821516146e+63, b_Curr_Intercept = 6.233782507766628e+62, Curr_Iteration_No = 90, Cost = 2.6704558450407453e+126
# m_Curr_Slope = -1.1062737145847259e+64, b_Curr_Intercept = -3.06420079783909e+63, Curr_Iteration_No = 91, Cost = 6.452329720249141e+127
# m_Curr_Slope = 5.43786183530713e+64, b_Curr_Intercept = 1.506200531985134e+64, Curr_Iteration_No = 92, Cost = 1.55900569920021e+129
# m_Curr_Slope = -2.6729679056859784e+65, b_Curr_Intercept = -7.403692486968129e+64, Curr_Iteration_No = 93, Cost = 3.7668545711654794e+130
# m_Curr_Slope = 1.3138909448632124e+66, b_Curr_Intercept = 3.639267234180561e+65, Curr_Iteration_No = 94, Cost = 9.101437773825657e+131
# m_Curr_Slope = -6.458399337011541e+66, b_Curr_Intercept = -1.788873055585791e+66, Curr_Iteration_No = 95, Cost = 2.1990806383903139e+133
# m_Curr_Slope = 3.174610659993062e+67, b_Curr_Intercept = 8.793162477724416e+66, Curr_Iteration_No = 96, Cost = 5.313397481055816e+134
# m_Curr_Slope = -1.560472234162744e+68, b_Curr_Intercept = -4.322257866103372e+67, Curr_Iteration_No = 97, Cost = 1.28381798733655e+136
# m_Curr_Slope = 7.670463733647855e+68, b_Curr_Intercept = 2.1245954579389478e+68, Curr_Iteration_No = 98, Cost = 3.101948669349995e+137
# m_Curr_Slope = -3.770397998832377e+69, b_Curr_Intercept = -1.044339787150231e+69, Curr_Iteration_No = 99, Cost = 7.494898530939337e+138
# m_Curr_Slope = 1.8533300675471045e+70, b_Curr_Intercept = 5.1334271046734496e+69, Curr_Iteration_No = 100, Cost = 1.8109101721804969e+140
# m_Curr_Slope = -9.10999936966299e+70, b_Curr_Intercept = -2.523323746086984e+70, Curr_Iteration_No = 101, Cost = 4.3755037351997216e+141
# m_Curr_Slope = 4.477998278261393e+71, b_Curr_Intercept = 1.2403337181450992e+71, Curr_Iteration_No = 102, Cost = 1.0572050028132756e+143
# m_Curr_Slope = -2.2011492829393917e+72, b_Curr_Intercept = -6.096830558319539e+71, Curr_Iteration_No = 103, Cost = 2.5544085563953945e+144
# m_Curr_Slope = 1.0819696356975193e+73, b_Curr_Intercept = 2.99688239649311e+72, Curr_Iteration_No = 104, Cost = 6.171937377918798e+145
# m_Curr_Slope = -5.318395720112804e+73, b_Curr_Intercept = -1.4731103337216237e+73, Curr_Iteration_No = 105, Cost = 1.4912575712126927e+147
# m_Curr_Slope = 2.614244624109005e+74, b_Curr_Intercept = 7.241038413308394e+73, Curr_Iteration_No = 106, Cost = 3.6031621961288766e+148
# m_Curr_Slope = -1.2850256570486782e+75, b_Curr_Intercept = -3.5593150154980886e+74, Curr_Iteration_No = 107, Cost = 8.705925832151621e+149
# m_Curr_Slope = 6.316512709043766e+75, b_Curr_Intercept = 1.7495727347981127e+75, Curr_Iteration_No = 108, Cost = 2.103517423566295e+151
# m_Curr_Slope = -3.104866629289412e+76, b_Curr_Intercept = -8.599982696166593e+75, Curr_Iteration_No = 109, Cost = 5.08249856081467e+152
# m_Curr_Slope = 1.5261897236227345e+77, b_Curr_Intercept = 4.2273008091257885e+76, Curr_Iteration_No = 110, Cost = 1.2280284123764504e+154
# m_Curr_Slope = -7.501948877671176e+77, b_Curr_Intercept = -2.0779195449778127e+77, Curr_Iteration_No = 111, Cost = 2.9671504350846298e+155
# m_Curr_Slope = 3.687564926698701e+78, b_Curr_Intercept = 1.0213963544017859e+78, Curr_Iteration_No = 112, Cost = 7.169200334205346e+156
# m_Curr_Slope = -1.8126136701746836e+79, b_Curr_Intercept = -5.02064921284716e+78, Curr_Iteration_No = 113, Cost = 1.7322152872408728e+158
# m_Curr_Slope = 8.909858897713151e+79, b_Curr_Intercept = 2.467888044619668e+79, Curr_Iteration_No = 114, Cost = 4.185361911334525e+159
# m_Curr_Slope = -4.379619710663868e+80, b_Curr_Intercept = -1.2130844324259897e+80, Curr_Iteration_No = 115, Cost = 1.0112631182670038e+161
# m_Curr_Slope = 2.1527915346626394e+81, b_Curr_Intercept = 5.962887349782808e+80, Curr_Iteration_No = 116, Cost = 2.443404216962985e+162
# m_Curr_Slope = -1.05819950084493e+82, b_Curr_Intercept = -2.9310429345048193e+81, Curr_Iteration_No = 117, Cost = 5.903729760958397e+163
# m_Curr_Slope = 5.201554193977908e+82, b_Curr_Intercept = 1.4407471045421541e+82, Curr_Iteration_No = 118, Cost = 1.4264535048460992e+165
# m_Curr_Slope = -2.556811452971382e+83, b_Curr_Intercept = -7.081957738695786e+82, Curr_Iteration_No = 119, Cost = 3.446583234455841e+166
# m_Curr_Slope = 1.2567945199175585e+84, b_Curr_Intercept = 3.481119292522283e+83, Curr_Iteration_No = 120, Cost = 8.327601251408265e+167
# m_Curr_Slope = -6.177743233507355e+84, b_Curr_Intercept = -1.7111358152502237e+84, Curr_Iteration_No = 121, Cost = 2.0121070023543354e+169
# m_Curr_Slope = 3.0366548273658433e+85, b_Curr_Intercept = 8.411046942635922e+84, Curr_Iteration_No = 122, Cost = 4.86163358054482e+170
# m_Curr_Slope = -1.4926603764541687e+86, b_Curr_Intercept = -4.1344298939169694e+85, Curr_Iteration_No = 123, Cost = 1.1746632283385303e+172
# m_Curr_Slope = 7.337136178131305e+86, b_Curr_Intercept = 2.0322690699854045e+86, Curr_Iteration_No = 124, Cost = 2.838209990840293e+173
# m_Curr_Slope = -3.6065516406568986e+87, b_Curr_Intercept = -9.989569732204255e+86, Curr_Iteration_No = 125, Cost = 6.8576556733621815e+174
# m_Curr_Slope = 1.7727917842786683e+88, b_Curr_Intercept = 4.910348974375136e+87, Curr_Iteration_No = 126, Cost = 1.65694016602603e+176
# m_Curr_Slope = -8.714115375410278e+88, b_Curr_Intercept = -2.413670227699246e+88, Curr_Iteration_No = 127, Cost = 4.0034828876794913e+177
# m_Curr_Slope = 4.283402453089512e+89, b_Curr_Intercept = 1.1864337949265795e+89, Curr_Iteration_No = 128, Cost = 9.673176835578457e+178
# m_Curr_Slope = -2.105496173129267e+90, b_Curr_Intercept = -5.831886782170978e+89, Curr_Iteration_No = 129, Cost = 2.3372236804191044e+180
# m_Curr_Slope = 1.0349515796407348e+91, b_Curr_Intercept = 2.866649920585351e+90, Curr_Iteration_No = 130, Cost = 5.6471773701272964e+181
# m_Curr_Slope = -5.087279596471109e+91, b_Curr_Intercept = -1.4090948734318347e+91, Curr_Iteration_No = 131, Cost = 1.3644655630033372e+183
# m_Curr_Slope = 2.5006400494267742e+92, b_Curr_Intercept = 6.926371957990745e+91, Curr_Iteration_No = 132, Cost = 3.2968085657632645e+184
# m_Curr_Slope = -1.2291836016119097e+93, b_Curr_Intercept = -3.4046414762406244e+92, Curr_Iteration_No = 133, Cost = 7.965717137899987e+185
# m_Curr_Slope = 6.042022428689688e+93, b_Curr_Intercept = 1.6735433286058334e+93, Curr_Iteration_No = 134, Cost = 1.924668911018291e+187
# m_Curr_Slope = -2.9699415922012342e+94, b_Curr_Intercept = -8.226261978731615e+93, Curr_Iteration_No = 135, Cost = 4.650366505503253e+188
# m_Curr_Slope = 1.45986764617153e+95, b_Curr_Intercept = 4.043599289365271e+94, Curr_Iteration_No = 136, Cost = 1.1236170809276926e+190
# m_Curr_Slope = -7.175944301176677e+95, b_Curr_Intercept = -1.9876215047890314e+95, Curr_Iteration_No = 137, Cost = 2.714872780582792e+191
# m_Curr_Slope = 3.5273181612478604e+96, b_Curr_Intercept = 9.770105699370501e+95, Curr_Iteration_No = 138, Cost = 6.559649492569127e+192
# m_Curr_Slope = -1.733844758052095e+97, b_Curr_Intercept = -4.802471956903265e+96, Curr_Iteration_No = 139, Cost = 1.5849361993354805e+194
# m_Curr_Slope = 8.522672204769918e+97, b_Curr_Intercept = 2.360643539232979e+97, Curr_Iteration_No = 140, Cost = 3.8295075961141775e+195
# m_Curr_Slope = -4.1892990230314096e+98, b_Curr_Intercept = -1.1603686537538387e+98, Curr_Iteration_No = 141, Cost = 9.252819409920009e+196
# m_Curr_Slope = 2.0592398584272101e+99, b_Curr_Intercept = 5.703764207670195e+98, Curr_Iteration_No = 142, Cost = 2.2356573236586903e+198
# m_Curr_Slope = -1.0122143994072977e+100, b_Curr_Intercept = -2.803671577257306e+99, Curr_Iteration_No = 143, Cost = 5.401773716095846e+199
# m_Curr_Slope = 4.975515533921436e+100, b_Curr_Intercept = 1.3781380202480815e+100, Curr_Iteration_No = 144, Cost = 1.3051713682198733e+201
# m_Curr_Slope = -2.4457026933018582e+101, b_Curr_Intercept = -6.774204290758114e+100, Curr_Iteration_No = 145, Cost = 3.1535425027987432e+202
# m_Curr_Slope = 1.202179276347208e+102, b_Curr_Intercept = 3.329843825414882e+101, Curr_Iteration_No = 146, Cost = 7.619559054932332e+203
# m_Curr_Slope = -5.909283317374668e+102, b_Curr_Intercept = -1.636776723250068e+102, Curr_Iteration_No = 147, Cost = 1.841030528051409e+205
# m_Curr_Slope = 2.9046940013061115e+103, b_Curr_Intercept = 8.045536614436969e+102, Curr_Iteration_No = 148, Cost = 4.4482802492661434e+206
# m_Curr_Slope = -1.4277953498043048e+104, b_Curr_Intercept = -3.9547641712373184e+103, Curr_Iteration_No = 149, Cost = 1.074789194123495e+208
# m_Curr_Slope = 7.018293699804971e+104, b_Curr_Intercept = 1.9439548161445915e+104, Curr_Iteration_No = 150, Cost = 2.5968953102610987e+209
# m_Curr_Slope = -3.449825387333926e+105, b_Curr_Intercept = -9.555463141635162e+104, Curr_Iteration_No = 151, Cost = 6.274593463842741e+210
# m_Curr_Slope = 1.6957533714247947e+106, b_Curr_Intercept = 4.696964923919132e+105, Curr_Iteration_No = 152, Cost = 1.5160612359278985e+212
# m_Curr_Slope = -8.335434909999448e+106, b_Curr_Intercept = -2.308781810941236e+106, Curr_Iteration_No = 153, Cost = 3.6630925721769324e+213
# m_Curr_Slope = 4.097262981140938e+107, b_Curr_Intercept = 1.1348761459528555e+107, Curr_Iteration_No = 154, Cost = 8.850729030166935e+214
# m_Curr_Slope = -2.0139997634063502e+108, b_Curr_Intercept = -5.5784563987349794e+107, Curr_Iteration_No = 155, Cost = 2.1385046329551525e+216
# m_Curr_Slope = 9.899767395138822e+108, b_Curr_Intercept = 2.742076825172777e+108, Curr_Iteration_No = 156, Cost = 5.167034319526999e+217
# m_Curr_Slope = -4.866206851588386e+109, b_Curr_Intercept = -1.3478612680121845e+109, Curr_Iteration_No = 157, Cost = 1.248453861064408e+219
# m_Curr_Slope = 2.391972273416602e+110, b_Curr_Intercept = 6.625379643376488e+109, Curr_Iteration_No = 158, Cost = 3.016502207690598e+220
# m_Curr_Slope = -1.1757682176881182e+111, b_Curr_Intercept = -3.256689427956078e+110, Curr_Iteration_No = 159, Cost = 7.288443612360953e+221
# m_Curr_Slope = 5.779460393789944e+111, b_Curr_Intercept = 1.6008178551343735e+111, Curr_Iteration_No = 160, Cost = 1.7610267333845038e+223
# m_Curr_Slope = -2.840879855475631e+112, b_Curr_Intercept = -7.86878166311773e+111, Curr_Iteration_No = 161, Cost = 4.25497585031095e+224
# m_Curr_Slope = 1.3964276599108002e+113, b_Curr_Intercept = 3.8678807000575605e+112, Curr_Iteration_No = 162, Cost = 1.0280831712267019e+226
# m_Curr_Slope = -6.864106574607235e+113, b_Curr_Intercept = -1.9012474548633224e+113, Curr_Iteration_No = 163, Cost = 2.4840446670979585e+227
# m_Curr_Slope = 3.3740350768027545e+114, b_Curr_Intercept = 9.34553613447919e+113, Curr_Iteration_No = 164, Cost = 6.001924825571489e+228
# m_Curr_Slope = -1.658498826578427e+115, b_Curr_Intercept = -4.593775808480172e+114, Curr_Iteration_No = 165, Cost = 1.4501793018841387e+230
# m_Curr_Slope = 8.152311090874948e+115, b_Curr_Intercept = 2.2580594494436324e+115, Curr_Iteration_No = 166, Cost = 3.5039092769925234e+231
# m_Curr_Slope = -4.0072489083102715e+116, b_Curr_Intercept = -1.1099436911590606e+116, Curr_Iteration_No = 167, Cost = 8.46611188384977e+232
# m_Curr_Slope = 1.9697535624134817e+117, b_Curr_Intercept = 5.455901516885878e+116, Curr_Iteration_No = 168, Cost = 2.0455738081033443e+234
# m_Curr_Slope = -9.68227625839355e+117, b_Curr_Intercept = -2.681835267775929e+117, Curr_Iteration_No = 169, Cost = 4.9424957546104046e+235
# m_Curr_Slope = 4.759299606443487e+118, b_Curr_Intercept = 1.3182496753702358e+118, Curr_Iteration_No = 170, Cost = 1.1942010690385085e+237
# m_Curr_Slope = -2.3394222742051047e+119, b_Curr_Intercept = -6.479824571980112e+118, Curr_Iteration_No = 171, Cost = 2.8854171335654106e+238
# m_Curr_Slope = 1.149937391971999e+120, b_Curr_Intercept = 3.1851421827086508e+119, Curr_Iteration_No = 172, Cost = 6.971717117433231e+239
# m_Curr_Slope = -5.652489591280292e+120, b_Curr_Intercept = -1.565648978822566e+120, Curr_Iteration_No = 173, Cost = 1.6844995824036082e+241
# m_Curr_Slope = 2.778467662899516e+121, b_Curr_Intercept = 7.695909897509155e+120, Curr_Iteration_No = 174, Cost = 4.070071684380996e+242
# m_Curr_Slope = -1.3657490967674196e+122, b_Curr_Intercept = -3.782905999473816e+121, Curr_Iteration_No = 175, Cost = 9.83406804551576e+243
# m_Curr_Slope = 6.71330683537446e+122, b_Curr_Intercept = 1.8594783451774385e+122, Curr_Iteration_No = 176, Cost = 2.3760980597702242e+245
# m_Curr_Slope = -3.299909827695123e+123, b_Curr_Intercept = -9.14022108047297e+122, Curr_Iteration_No = 177, Cost = 5.741105271503868e+246
# m_Curr_Slope = 1.6220627386699002e+124, b_Curr_Intercept = 4.492853687519036e+123, Curr_Iteration_No = 178, Cost = 1.3871603321656198e+248
# m_Curr_Slope = -7.973210377142406e+124, b_Curr_Intercept = -2.2084514236288987e+124, Curr_Iteration_No = 179, Cost = 3.3516434486660978e+249
# m_Curr_Slope = 3.919212383258418e+125, b_Curr_Intercept = 1.0855589853899161e+125, Curr_Iteration_No = 180, Cost = 8.098208654401706e+250
# m_Curr_Slope = -1.9264794202747758e+126, b_Curr_Intercept = -5.336039082192669e+125, Curr_Iteration_No = 181, Cost = 1.956681383764938e+252
# m_Curr_Slope = 9.469563253565391e+126, b_Curr_Intercept = 2.6229171763025304e+126, Curr_Iteration_No = 182, Cost = 4.727714734160712e+253
# m_Curr_Slope = -4.654741040549807e+127, b_Curr_Intercept = -1.2892886292196822e+127, Curr_Iteration_No = 183, Cost = 1.1423058855189383e+255
# m_Curr_Slope = 2.2880267626303658e+128, b_Curr_Intercept = 6.337467246214868e+127, Curr_Iteration_No = 184, Cost = 2.7600284904305918e+256
# m_Curr_Slope = -1.1246740518768875e+129, b_Curr_Intercept = -3.1151667816348055e+128, Curr_Iteration_No = 185, Cost = 6.668754284258897e+257
# m_Curr_Slope = 5.5283082506912144e+129, b_Curr_Intercept = 1.531252738733591e+129, Curr_Iteration_No = 186, Cost = 1.6112979941335042e+259
# m_Curr_Slope = -2.717426623621085e+130, b_Curr_Intercept = -7.526836006670027e+129, Curr_Iteration_No = 187, Cost = 3.8932027110775185e+260
# m_Curr_Slope = 1.3357445207295388e+131, b_Curr_Intercept = 3.6997981350981263e+130, Curr_Iteration_No = 188, Cost = 9.40671893388176e+261
# m_Curr_Slope = -6.5658200635476454e+131, b_Curr_Intercept = -1.8186268743394023e+131, Curr_Iteration_No = 189, Cost = 2.272842378571121e+263
# m_Curr_Slope = 3.227413059747351e+132, b_Curr_Intercept = 8.939416658151768e+131, Curr_Iteration_No = 190, Cost = 5.491619888016699e+264
# m_Curr_Slope = -1.5864271267585847e+133, b_Curr_Intercept = -4.394148756713438e+132, Curr_Iteration_No = 191, Cost = 1.3268799138381098e+266
# m_Curr_Slope = 7.798044383920646e+133, b_Curr_Intercept = 2.159933252302205e+133, Curr_Iteration_No = 192, Cost = 3.2059944818629367e+267
# m_Curr_Slope = -3.833109960609622e+134, b_Curr_Intercept = -1.0617099949729868e+134, Curr_Iteration_No = 193, Cost = 7.746293022105125e+268
# m_Curr_Slope = 1.8841559815202783e+135, b_Curr_Intercept = 5.218809943427941e+134, Curr_Iteration_No = 194, Cost = 1.8716518672685576e+270
# m_Curr_Slope = -9.261523408355443e+135, b_Curr_Intercept = -2.5652934751090202e+135, Curr_Iteration_No = 195, Cost = 4.522267234473765e+271
# m_Curr_Slope = 4.552479555026302e+136, b_Curr_Intercept = 1.260963837497866e+136, Curr_Iteration_No = 196, Cost = 1.092665858306253e+273
# m_Curr_Slope = -2.2377603753865163e+137, b_Curr_Intercept = -6.19823741379052e+136, Curr_Iteration_No = 197, Cost = 2.640088734267539e+274
# m_Curr_Slope = 1.0999657301307904e+138, b_Curr_Intercept = 3.046728692390249e+137, Curr_Iteration_No = 198, Cost = 6.378956999361833e+275
# m_Curr_Slope = -5.4068550894470946e+138, b_Curr_Intercept = -1.497612160576673e+138, Curr_Iteration_No = 199, Cost = 1.541277452971541e+277
# m_Curr_Slope = 2.657726614337694e+139, b_Curr_Intercept = 7.361476553882307e+138, Curr_Iteration_No = 200, Cost = 3.724019753191777e+278
# m_Curr_Slope = -1.3063991247601972e+140, b_Curr_Intercept = -3.618516093812426e+139, Curr_Iteration_No = 201, Cost = 8.997940698752707e+279
# m_Curr_Slope = 6.421573475492751e+140, b_Curr_Intercept = 1.7786728824496745e+140, Curr_Iteration_No = 202, Cost = 2.1740737746860442e+281
# m_Curr_Slope = -3.156508996339189e+141, b_Curr_Intercept = -8.74302377201429e+140, Curr_Iteration_No = 203, Cost = 5.252976137565368e+282
# m_Curr_Slope = 1.5515744049328494e+142, b_Curr_Intercept = 4.297612305908069e+141, Curr_Iteration_No = 204, Cost = 1.2692190404539492e+284
# m_Curr_Slope = -7.626726668084032e+142, b_Curr_Intercept = -2.1124809921038706e+142, Curr_Iteration_No = 205, Cost = 3.0666748343491744e+285
# m_Curr_Slope = 3.7488991494533955e+143, b_Curr_Intercept = 1.0383849506074115e+143, Curr_Iteration_No = 206, Cost = 7.409670230181013e+286
# m_Curr_Slope = -1.84276235984514e+144, b_Curr_Intercept = -5.104156248876388e+143, Curr_Iteration_No = 207, Cost = 1.7903173921496826e+288
# m_Curr_Slope = 9.058054056634589e+144, b_Curr_Intercept = 2.5089357273238907e+144, Curr_Iteration_No = 208, Cost = 4.325747658213042e+289
# m_Curr_Slope = -4.45246468458415e+145, b_Curr_Intercept = -1.2332613221289939e+145, Curr_Iteration_No = 209, Cost = 1.0451829873622298e+291
# m_Curr_Slope = 2.188598306382217e+146, b_Curr_Intercept = 6.06206636581173e+145, Curr_Iteration_No = 210, Cost = 2.5253610783267615e+292
# m_Curr_Slope = -1.0758002333591737e+147, b_Curr_Intercept = -2.979794141282739e+146, Curr_Iteration_No = 211, Cost = 6.101753140876054e+293
# m_Curr_Slope = 5.2880701713086934e+147, b_Curr_Intercept = 1.4647106429746239e+147, Curr_Iteration_No = 212, Cost = 1.4742997233828974e+295
# m_Curr_Slope = -2.5993381735351056e+148, b_Curr_Intercept = -7.199749935475729e+147, Curr_Iteration_No = 213, Cost = 3.5621888073545034e+296
# m_Curr_Slope = 1.2776984271229335e+149, b_Curr_Intercept = 3.5390197635288723e+148, Curr_Iteration_No = 214, Cost = 8.606926324401222e+297
# m_Curr_Slope = -6.280495886582531e+149, b_Curr_Intercept = -1.7395966525079567e+149, Curr_Iteration_No = 215, Cost = 2.0795972577513772e+299
# m_Curr_Slope = 3.087162646838333e+150, b_Curr_Intercept = 8.550945503619818e+149, Curr_Iteration_No = 216, Cost = 5.024702886309318e+300
# m_Curr_Slope = -1.5174873736315473e+151, b_Curr_Intercept = -4.2031966950765095e+150, Curr_Iteration_No = 217, Cost = 1.2140638771078644e+302
# m_Curr_Slope = 7.459172685603441e+151, b_Curr_Intercept = 2.0660712256934958e+151, Curr_Iteration_No = 218, Cost = 2.9334094593218974e+303
# m_Curr_Slope = -3.666538392375573e+152, b_Curr_Intercept = -1.0155723415558412e+152, Curr_Iteration_No = 219, Cost = 7.087675713190404e+304
# m_Curr_Slope = 1.8022781278023844e+153, b_Curr_Intercept = 4.99202141778544e+152, Curr_Iteration_No = 220, Cost = 1.712517386746333e+306
# m_Curr_Slope = -8.859054787778549e+153, b_Curr_Intercept = -2.453816120814305e+153, Curr_Iteration_No = 221, Cost = inf
# m_Curr_Slope = 4.3546470726224926e+154, b_Curr_Intercept = 1.206167412126067e+154, Curr_Iteration_No = 222, Cost = inf
# m_Curr_Slope = -2.140516294499032e+155, b_Curr_Intercept = -5.928886902870705e+154, Curr_Iteration_No = 223, Cost = inf
# m_Curr_Slope = 1.0521656360676252e+156, b_Curr_Intercept = 2.914330096605013e+155, Curr_Iteration_No = 224, Cost = inf
# m_Curr_Slope = -5.171894876795065e+156, b_Curr_Intercept = -1.4325319492711874e+156, Curr_Iteration_No = 225, Cost = inf
# m_Curr_Slope = 2.542232486948458e+157, b_Curr_Intercept = 7.041576340557007e+156, Curr_Iteration_No = 226, Cost = inf
# m_Curr_Slope = -1.2496282642351614e+158, b_Curr_Intercept = -3.461269913394837e+157, Curr_Iteration_No = 227, Cost = inf
# m_Curr_Slope = 6.142517676067451e+158, b_Curr_Intercept = 1.7013789006830006e+158, Curr_Iteration_No = 228, Cost = inf
# m_Curr_Slope = -3.0193397893328034e+159, b_Curr_Intercept = -8.363087063759678e+158, Curr_Iteration_No = 229, Cost = inf
# m_Curr_Slope = 1.484149211156157e+160, b_Curr_Intercept = 4.110855330811222e+159, Curr_Iteration_No = 230, Cost = inf
# m_Curr_Slope = -7.295299749824389e+160, b_Curr_Intercept = -2.020681050193674e+160, Curr_Iteration_No = 231, Cost = inf
# m_Curr_Slope = 3.585987044950027e+161, b_Curr_Intercept = 9.932609099639748e+160, Curr_Iteration_No = 232, Cost = inf
# m_Curr_Slope = -1.7626833067221084e+162, b_Curr_Intercept = -4.882350112443054e+161, Curr_Iteration_No = 233, Cost = inf
# m_Curr_Slope = 8.664427397115946e+162, b_Curr_Intercept = 2.39990745446101e+162, Curr_Iteration_No = 234, Cost = inf
# m_Curr_Slope = -4.2589784468713274e+163, b_Curr_Intercept = -1.1796687368443415e+163, Curr_Iteration_No = 235, Cost = inf
# m_Curr_Slope = 2.093490611618749e+164, b_Curr_Intercept = 5.79863330188482e+163, Curr_Iteration_No = 236, Cost = inf
# m_Curr_Slope = -1.0290502747567095e+165, b_Curr_Intercept = -2.850304252333883e+164, Curr_Iteration_No = 237, Cost = inf
# m_Curr_Slope = 5.058271874255275e+165, b_Curr_Intercept = 1.40106019951837e+165, Curr_Iteration_No = 238, Cost = inf
# m_Curr_Slope = -2.4863813733426297e+166, b_Curr_Intercept = -6.886877711623729e+165, Curr_Iteration_No = 239, Cost = inf
# m_Curr_Slope = 1.2221747836785393e+167, b_Curr_Intercept = 3.385228174432758e+166, Curr_Iteration_No = 240, Cost = inf
# m_Curr_Slope = -6.007570752718341e+167, b_Curr_Intercept = -1.664000766796171e+167, Curr_Iteration_No = 241, Cost = inf
# m_Curr_Slope = 2.9530069537426796e+168, b_Curr_Intercept = 8.179355745679424e+167, Curr_Iteration_No = 242, Cost = inf
# m_Curr_Slope = -1.4515434653693973e+169, b_Curr_Intercept = -4.020542643330048e+168, Curr_Iteration_No = 243, Cost = inf
# m_Curr_Slope = 7.135026990661795e+169, b_Curr_Intercept = 1.9762880658875936e+169, Curr_Iteration_No = 244, Cost = inf
# m_Curr_Slope = -3.5072053556809465e+170, b_Curr_Intercept = -9.714396453048896e+169, Curr_Iteration_No = 245, Cost = inf
# m_Curr_Slope = 1.7239583568521592e+171, b_Curr_Intercept = 4.775088210868976e+170, Curr_Iteration_No = 246, Cost = inf
# m_Curr_Slope = -8.474075837465063e+171, b_Curr_Intercept = -2.34718312473479e+171, Curr_Iteration_No = 247, Cost = inf
# m_Curr_Slope = 4.165411595569496e+172, b_Curr_Intercept = 1.15375221938302e+172, Curr_Iteration_No = 248, Cost = inf
# m_Curr_Slope = -2.0474980509137263e+173, b_Curr_Intercept = -5.671241283662735e+172, Curr_Iteration_No = 249, Cost = inf
# m_Curr_Slope = 1.006442742166118e+174, b_Curr_Intercept = 2.787685012187453e+173, Curr_Iteration_No = 250, Cost = inf
# m_Curr_Slope = -4.9471450915756494e+174, b_Curr_Intercept = -1.3702798626398042e+174, Curr_Iteration_No = 251, Cost = inf
# m_Curr_Slope = 2.4317572706050133e+175, b_Curr_Intercept = 6.735577706043572e+174, Curr_Iteration_No = 252, Cost = inf
# m_Curr_Slope = -1.1953244373629097e+176, b_Curr_Intercept = -3.310857020605342e+175, Curr_Iteration_No = 253, Cost = inf
# m_Curr_Slope = 5.875588521223896e+176, b_Curr_Intercept = 1.627443805014098e+176, Curr_Iteration_No = 254, Cost = inf
# m_Curr_Slope = -2.888131405302868e+177, b_Curr_Intercept = -7.999660879328795e+176, Curr_Iteration_No = 255, Cost = inf
# m_Curr_Slope = 1.4196540455762224e+178, b_Curr_Intercept = 3.932214063987862e+177, Curr_Iteration_No = 256, Cost = inf
# m_Curr_Slope = -6.97827531469118e+178, b_Curr_Intercept = -1.9328703651649404e+178, Curr_Iteration_No = 257, Cost = inf
# m_Curr_Slope = 3.4301544463857717e+179, b_Curr_Intercept = 9.5009777894543e+178, Curr_Iteration_No = 258, Cost = inf
# m_Curr_Slope = -1.6860841677154116e+180, b_Curr_Intercept = -4.6701827801059424e+179, Curr_Iteration_No = 259, Cost = inf
# m_Curr_Slope = 8.287906171735244e+180, b_Curr_Intercept = 2.2956171125678207e+180, Curr_Iteration_No = 260, Cost = inf
# m_Curr_Slope = -4.073900344166034e+181, b_Curr_Intercept = -1.1284050701318955e+181, Curr_Iteration_No = 261, Cost = inf
# m_Curr_Slope = 2.0025159153944996e+182, b_Curr_Intercept = 5.546647981183104e+181, Curr_Iteration_No = 262, Cost = inf
# m_Curr_Slope = -9.843318816452712e+182, b_Curr_Intercept = -2.7264414740325945e+182, Curr_Iteration_No = 263, Cost = inf
# m_Curr_Slope = 4.83845968850861e+183, b_Curr_Intercept = 1.3401757487662773e+183, Curr_Iteration_No = 264, Cost = inf
# m_Curr_Slope = -2.3783332221438164e+184, b_Curr_Intercept = -6.587601658379777e+183, Curr_Iteration_No = 265, Cost = inf
# m_Curr_Slope = 1.1690639748404141e+185, b_Curr_Intercept = 3.238119750296736e+184, Curr_Iteration_No = 266, Cost = inf
# m_Curr_Slope = -5.746505849326376e+185, b_Curr_Intercept = -1.5916899747457845e+185, Curr_Iteration_No = 267, Cost = inf
# m_Curr_Slope = 2.8246811284087366e+186, b_Curr_Intercept = 7.823913786616672e+185, Curr_Iteration_No = 268, Cost = inf
# m_Curr_Slope = -1.3884652145831815e+187, b_Curr_Intercept = -3.845826003282272e+186, Curr_Iteration_No = 269, Cost = inf
# m_Curr_Slope = 6.8249673661166596e+187, b_Curr_Intercept = 1.8904065217106586e+187, Curr_Iteration_No = 270, Cost = inf
# m_Curr_Slope = -3.354796293009096e+188, b_Curr_Intercept = -9.292247788319661e+187, Curr_Iteration_No = 271, Cost = inf
# m_Curr_Slope = 1.6490420486788884e+189, b_Curr_Intercept = 4.5675820500976607e+188, Curr_Iteration_No = 272, Cost = inf
# m_Curr_Slope = -8.105826526569648e+189, b_Curr_Intercept = -2.2451839705134494e+189, Curr_Iteration_No = 273, Cost = inf
# m_Curr_Slope = 3.98439953253336e+190, b_Curr_Intercept = 1.1036147804597748e+190, Curr_Iteration_No = 274, Cost = inf
# m_Curr_Slope = -1.9585220067089783e+191, b_Curr_Intercept = -5.424791908570153e+190, Curr_Iteration_No = 275, Cost = inf
# m_Curr_Slope = 9.627067816475926e+191, b_Curr_Intercept = 2.6665434146349597e+191, Curr_Iteration_No = 276, Cost = inf
# m_Curr_Slope = -4.73216202960941e+192, b_Curr_Intercept = -1.3107330017396405e+192, Curr_Iteration_No = 277, Cost = inf
# m_Curr_Slope = 2.3260828635851803e+193, b_Curr_Intercept = 6.442876543544294e+192, Curr_Iteration_No = 278, Cost = inf
# m_Curr_Slope = -1.1433804367664956e+194, b_Curr_Intercept = -3.166980468200556e+193, Curr_Iteration_No = 279, Cost = inf
# m_Curr_Slope = 5.620259035679313e+194, b_Curr_Intercept = 1.556721631739716e+194, Curr_Iteration_No = 280, Cost = inf
# m_Curr_Slope = -2.762624810816648e+195, b_Curr_Intercept = -7.652027737649113e+194, Curr_Iteration_No = 281, Cost = inf
# m_Curr_Slope = 1.3579615809322284e+196, b_Curr_Intercept = 3.7613358293425177e+195, Curr_Iteration_No = 282, Cost = inf
# m_Curr_Slope = -6.675027488596405e+196, b_Curr_Intercept = -1.8488755799312167e+196, Curr_Iteration_No = 283, Cost = inf
# m_Curr_Slope = 3.281093706858065e+197, b_Curr_Intercept = 9.088103442929e+196, Curr_Iteration_No = 284, Cost = inf
# m_Curr_Slope = -1.6128137197300645e+198, b_Curr_Intercept = -4.467235388140648e+197, Curr_Iteration_No = 285, Cost = inf
# m_Curr_Slope = 7.927747047006388e+198, b_Curr_Intercept = 2.1958588101880646e+198, Curr_Iteration_No = 286, Cost = inf
# m_Curr_Slope = -3.896864992681085e+199, b_Curr_Intercept = -1.0793691165415551e+199, Curr_Iteration_No = 287, Cost = inf
# m_Curr_Slope = 1.9154946141877214e+200, b_Curr_Intercept = 5.30561293075085e+199, Curr_Iteration_No = 288, Cost = inf
# m_Curr_Slope = -9.415567703457377e+200, b_Curr_Intercept = -2.6079612747440393e+200, Curr_Iteration_No = 289, Cost = inf
# m_Curr_Slope = 4.628199657767426e+201, b_Curr_Intercept = 1.2819370917814045e+201, Curr_Iteration_No = 290, Cost = inf
# m_Curr_Slope = -2.2749804097625523e+202, b_Curr_Intercept = -6.301330940760436e+201, Curr_Iteration_No = 291, Cost = inf
# m_Curr_Slope = 1.1182611485045554e+203, b_Curr_Intercept = 3.0974040676058067e+202, Curr_Iteration_No = 292, Cost = inf
# m_Curr_Slope = -5.496785778411371e+203, b_Curr_Intercept = -1.5225215193765427e+203, Curr_Iteration_No = 293, Cost = inf
# m_Curr_Slope = 2.701931828191599e+204, b_Curr_Intercept = 7.483917907928786e+203, Curr_Iteration_No = 294, Cost = inf
# m_Curr_Slope = -1.3281280913051512e+205, b_Curr_Intercept = -3.678701846890959e+204, Curr_Iteration_No = 295, Cost = inf
# m_Curr_Slope = 6.528381687906823e+205, b_Curr_Intercept = 1.8082570446131788e+205, Curr_Iteration_No = 296, Cost = inf
# m_Curr_Slope = -3.2090103162500472e+206, b_Curr_Intercept = -8.888444009553645e+205, Curr_Iteration_No = 297, Cost = inf
# m_Curr_Slope = 1.5773813024558262e+207, b_Curr_Intercept = 4.369093273897389e+206, Curr_Iteration_No = 298, Cost = inf
# m_Curr_Slope = -7.753579852135826e+207, b_Curr_Intercept = -2.1476172899888702e+207, Curr_Iteration_No = 299, Cost = inf
# m_Curr_Slope = 3.8112535269594527e+208, b_Curr_Intercept = 1.0556561133209307e+208, Curr_Iteration_No = 300, Cost = inf
# m_Curr_Slope = -1.873412504129893e+209, b_Curr_Intercept = -5.189052233778714e+208, Curr_Iteration_No = 301, Cost = inf
# m_Curr_Slope = 9.208714103651327e+209, b_Curr_Intercept = 2.550666144505904e+209, Curr_Iteration_No = 302, Cost = inf
# m_Curr_Slope = -4.5265212683189824e+210, b_Curr_Intercept = -1.2537738083224037e+210, Curr_Iteration_No = 303, Cost = inf
# m_Curr_Slope = 2.225000641991903e+211, b_Curr_Intercept = 6.162894998317272e+210, Curr_Iteration_No = 304, Cost = inf
# m_Curr_Slope = -1.0936937138711155e+212, b_Curr_Intercept = -3.0293562130719915e+211, Curr_Iteration_No = 305, Cost = inf
# m_Curr_Slope = 5.376025144380819e+212, b_Curr_Intercept = 1.4890727601530738e+212, Curr_Iteration_No = 306, Cost = inf
# m_Curr_Slope = -2.6425722289943296e+213, b_Curr_Intercept = -7.319501336494692e+212, Curr_Iteration_No = 307, Cost = inf
# m_Curr_Slope = 1.2989500230948689e+214, b_Curr_Intercept = 3.5978832766667605e+213, Curr_Iteration_No = 308, Cost = inf
# m_Curr_Slope = -6.384957595426924e+214, b_Curr_Intercept = -1.7685308708089652e+214, Curr_Iteration_No = 309, Cost = inf
# m_Curr_Slope = 3.1385105485634605e+215, b_Curr_Intercept = 8.693170957735904e+214, Curr_Iteration_No = 310, Cost = inf
# m_Curr_Slope = -1.542727311219596e+216, b_Curr_Intercept = -4.273107274958396e+215, Curr_Iteration_No = 311, Cost = inf
# m_Curr_Slope = 7.583238991731941e+216, b_Curr_Intercept = 2.1004356030814744e+216, Curr_Iteration_No = 312, Cost = inf
# m_Curr_Slope = -3.727522886741595e+217, b_Curr_Intercept = -1.0324640686057176e+217, Curr_Iteration_No = 313, Cost = inf
# m_Curr_Slope = 1.8322549093245755e+218, b_Curr_Intercept = 5.075052295809534e+217, Curr_Iteration_No = 314, Cost = inf
# m_Curr_Slope = -9.006404936332022e+218, b_Curr_Intercept = -2.4946297491963866e+218, Curr_Iteration_No = 315, Cost = inf
# m_Curr_Slope = 4.427076683728867e+219, b_Curr_Intercept = 1.226229252989984e+219, Curr_Iteration_No = 316, Cost = inf
# m_Curr_Slope = -2.1761188956264877e+220, b_Curr_Intercept = -6.027500399098309e+219, Curr_Iteration_No = 317, Cost = inf
# m_Curr_Slope = 1.0696660090183942e+221, b_Curr_Intercept = 2.9628033234848164e+220, Curr_Iteration_No = 318, Cost = inf
# m_Curr_Slope = -5.257917539105497e+221, b_Curr_Intercept = -1.4563588473533507e+221, Curr_Iteration_No = 319, Cost = inf
# m_Curr_Slope = 2.5845167197004765e+222, b_Curr_Intercept = 7.15869688498157e+221, Curr_Iteration_No = 320, Cost = inf
# m_Curr_Slope = -1.2704129771399382e+223, b_Curr_Intercept = -3.518840235301637e+222, Curr_Iteration_No = 321, Cost = inf
# m_Curr_Slope = 6.244684432424968e+223, b_Curr_Intercept = 1.7296774539448253e+223, Curr_Iteration_No = 322, Cost = inf
# m_Curr_Slope = -3.069559612682959e+224, b_Curr_Intercept = -8.502187921665039e+223, Curr_Iteration_No = 323, Cost = inf
# m_Curr_Slope = 1.5088346445323074e+225, b_Curr_Intercept = 4.179230022941187e+224, Curr_Iteration_No = 324, Cost = inf
# m_Curr_Slope = -7.416640403836561e+225, b_Curr_Intercept = -2.0542904656514022e+225, Curr_Iteration_No = 325, Cost = inf
# m_Curr_Slope = 3.645631751574164e+226, b_Curr_Intercept = 1.009781537292914e+226, Curr_Iteration_No = 326, Cost = inf
# m_Curr_Slope = -1.7920015188023108e+227, b_Curr_Intercept = -4.96355685871479e+226, Curr_Iteration_No = 327, Cost = inf
# m_Curr_Slope = 8.808540363417617e+227, b_Curr_Intercept = 2.4398244352677267e+227, Curr_Iteration_No = 328, Cost = inf
# m_Curr_Slope = -4.3298168288280876e+228, b_Curr_Intercept = -1.1992898327492565e+228, Curr_Iteration_No = 329, Cost = inf
# m_Curr_Slope = 2.1283110478850277e+229, b_Curr_Intercept = 5.895080326867502e+228, Curr_Iteration_No = 330, Cost = inf
# m_Curr_Slope = -1.0461661764512751e+230, b_Curr_Intercept = -2.897712555484167e+229, Curr_Iteration_No = 331, Cost = inf
# m_Curr_Slope = 5.142404677353363e+230, b_Curr_Intercept = 1.4243636369027044e+230, Curr_Iteration_No = 332, Cost = inf
# m_Curr_Slope = -2.527736650344419e+231, b_Curr_Intercept = -7.001425197578692e+230, Curr_Iteration_No = 333, Cost = inf
# m_Curr_Slope = 1.242502870618669e+232, b_Curr_Intercept = 3.441533715637694e+231, Curr_Iteration_No = 334, Cost = inf
# m_Curr_Slope = -6.107492975129666e+232, b_Curr_Intercept = -1.6916776201461192e+232, Curr_Iteration_No = 335, Cost = inf
# m_Curr_Slope = 3.002123481830267e+233, b_Curr_Intercept = 8.31540065262144e+232, Curr_Iteration_No = 336, Cost = inf
# m_Curr_Slope = -1.4756865766129419e+234, b_Curr_Intercept = -4.0874151901143295e+233, Curr_Iteration_No = 337, Cost = inf
# m_Curr_Slope = 7.253701873275388e+234, b_Curr_Intercept = 2.0091591054136962e+234, Curr_Iteration_No = 338, Cost = inf
# m_Curr_Slope = -3.5655397087859795e+235, b_Curr_Intercept = -9.875973257206234e+234, Curr_Iteration_No = 339, Cost = inf
# m_Curr_Slope = 1.7526324678117842e+236, b_Curr_Intercept = 4.854510900318659e+235, Curr_Iteration_No = 340, Cost = inf
# m_Curr_Slope = -8.61502274020083e+236, b_Curr_Intercept = -2.386223156701744e+236, Curr_Iteration_No = 341, Cost = inf
# m_Curr_Slope = 4.234693706595635e+237, b_Curr_Intercept = 1.1729422531950375e+237, Curr_Iteration_No = 342, Cost = inf
# m_Curr_Slope = -2.0815535059472918e+238, b_Curr_Intercept = -5.7655694332959326e+237, Curr_Iteration_No = 343, Cost = inf
# m_Curr_Slope = 1.0231826191757204e+239, b_Curr_Intercept = 2.834051787256141e+238, Curr_Iteration_No = 344, Cost = inf
# m_Curr_Slope = -5.029429554379162e+239, b_Curr_Intercept = -1.3930713394007738e+239, Curr_Iteration_No = 345, Cost = inf
# m_Curr_Slope = 2.4722040003807392e+240, b_Curr_Intercept = 6.8476086618683565e+239, Curr_Iteration_No = 346, Cost = inf
# m_Curr_Slope = -1.215205930099358e+241, b_Curr_Intercept = -3.365925567477691e+240, Curr_Iteration_No = 347, Cost = inf
# m_Curr_Slope = 5.973315520568765e+241, b_Curr_Intercept = 1.6545126167751526e+241, Curr_Iteration_No = 348, Cost = inf
# m_Curr_Slope = -2.936168876772217e+242, b_Curr_Intercept = -8.13271697246557e+241, Curr_Iteration_No = 349, Cost = inf
# m_Curr_Slope = 1.4432667491344811e+243, b_Curr_Intercept = 3.9976174665350475e+242, Curr_Iteration_No = 350, Cost = inf
# m_Curr_Slope = -7.094342991085422e+243, b_Curr_Intercept = -1.9650192503749693e+243, Curr_Iteration_No = 351, Cost = inf
# m_Curr_Slope = 3.487207233544685e+244, b_Curr_Intercept = 9.65900486144065e+243, Curr_Iteration_No = 352, Cost = inf
# m_Curr_Slope = -1.714128328016718e+245, b_Curr_Intercept = -4.747860607244995e+244, Curr_Iteration_No = 353, Cost = inf
# m_Curr_Slope = 8.425756567161981e+245, b_Curr_Intercept = 2.3337994616628277e+245, Curr_Iteration_No = 354, Cost = inf
# m_Curr_Slope = -4.141660374472317e+246, b_Curr_Intercept = -1.147173511991156e+246, Curr_Iteration_No = 355, Cost = inf
# m_Curr_Slope = 2.0358231953112164e+247, b_Curr_Intercept = 5.638903805712898e+246, Curr_Iteration_No = 356, Cost = inf
# m_Curr_Slope = -1.0007039949757409e+248, b_Curr_Intercept = -2.7717896026811794e+247, Curr_Iteration_No = 357, Cost = inf
# m_Curr_Slope = 4.918936417793012e+248, b_Curr_Intercept = 1.3624665123295526e+248, Curr_Iteration_No = 358, Cost = inf
# m_Curr_Slope = -2.4178913648562887e+249, b_Curr_Intercept = -6.697171370524742e+248, Curr_Iteration_No = 359, Cost = inf
# m_Curr_Slope = 1.1885086847432012e+250, b_Curr_Intercept = 3.2919784787581965e+249, Curr_Iteration_No = 360, Cost = inf
# m_Curr_Slope = -5.842085853158137e+250, b_Curr_Intercept = -1.6181641031768918e+250, Curr_Iteration_No = 361, Cost = inf
# m_Curr_Slope = 2.871663249397696e+251, b_Curr_Intercept = 7.954046728148759e+250, Curr_Iteration_No = 362, Cost = inf
# m_Curr_Slope = -1.4115591631511949e+252, b_Curr_Intercept = -3.9097925376891064e+251, Curr_Iteration_No = 363, Cost = inf
# m_Curr_Slope = 6.9384851148337445e+252, b_Curr_Intercept = 1.9218491178423374e+252, Curr_Iteration_No = 364, Cost = inf
# m_Curr_Slope = -3.410595669351536e+253, b_Curr_Intercept = -9.446803113329449e+252, Curr_Iteration_No = 365, Cost = inf
# m_Curr_Slope = 1.676470097908133e+254, b_Curr_Intercept = 4.6435533483608315e+253, Curr_Iteration_No = 366, Cost = inf
# m_Curr_Slope = -8.240648442840722e+254, b_Curr_Intercept = -2.2825274794441577e+254, Curr_Iteration_No = 367, Cost = inf
# m_Curr_Slope = 4.050670921194949e+255, b_Curr_Intercept = 1.1219708924539005e+255, Curr_Iteration_No = 368, Cost = inf
# ...
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9805, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9806, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9807, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9808, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9809, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9810, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9811, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9812, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9813, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9814, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9815, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9816, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9817, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9818, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9819, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9820, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9821, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9822, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9823, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9824, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9825, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9826, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9827, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9828, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9829, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9830, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9831, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9832, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9833, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9834, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9835, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9836, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9837, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9838, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9839, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9840, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9841, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9842, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9843, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9844, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9845, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9846, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9847, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9848, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9849, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9850, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9851, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9852, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9853, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9854, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9855, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9856, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9857, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9858, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9859, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9860, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9861, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9862, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9863, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9864, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9865, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9866, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9867, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9868, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9869, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9870, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9871, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9872, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9873, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9874, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9875, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9876, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9877, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9878, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9879, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9880, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9881, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9882, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9883, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9884, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9885, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9886, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9887, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9888, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9889, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9890, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9891, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9892, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9893, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9894, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9895, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9896, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9897, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9898, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9899, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9900, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9901, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9902, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9903, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9904, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9905, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9906, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9907, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9908, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9909, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9910, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9911, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9912, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9913, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9914, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9915, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9916, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9917, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9918, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9919, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9920, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9921, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9922, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9923, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9924, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9925, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9926, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9927, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9928, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9929, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9930, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9931, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9932, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9933, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9934, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9935, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9936, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9937, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9938, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9939, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9940, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9941, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9942, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9943, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9944, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9945, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9946, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9947, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9948, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9949, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9950, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9951, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9952, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9953, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9954, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9955, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9956, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9957, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9958, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9959, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9960, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9961, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9962, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9963, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9964, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9965, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9966, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9967, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9968, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9969, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9970, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9971, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9972, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9973, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9974, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9975, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9976, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9977, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9978, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9979, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9980, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9981, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9982, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9983, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9984, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9985, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9986, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9987, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9988, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9989, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9990, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9991, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9992, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9993, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9994, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9995, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9996, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9997, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9998, Cost = nan
# m_Curr_Slope = nan, b_Curr_Intercept = nan, Curr_Iteration_No = 9999, Cost = nan

# %%
# Graphical representation of Gradient descent

import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

def gradient_descent(x,y):
    m_curr = b_curr = 0
    rate = 0.01
    n = len(x)
    plt.scatter(x,y,color='red',marker='+',linewidth='5')
    for i in range(10000):
        y_predicted = m_curr * x + b_curr
#         print (m_curr,b_curr, i)
        plt.plot(x,y_predicted,color='green')
        md = -(2/n)*sum(x*(y-y_predicted))
        yd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - rate * md
        b_curr = b_curr - rate * yd


x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])


gradient_descent(x,y)
# Out:
# Error in callback <function _draw_all_if_interactive at 0x00000136FDA0E7A0> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:268, in _draw_all_if_interactive()
#     266 def _draw_all_if_interactive() -> None:
#     267     if matplotlib.is_interactive():
# --> 268         draw_all()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\_pylab_helpers.py:131, in Gcf.draw_all(cls, force)
#     129 for manager in cls.get_all_fig_managers():
#     130     if force or manager.canvas.figure.stale:
# --> 131         manager.canvas.draw_idle()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\backend_bases.py:1905, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1903 if not self._is_idle_drawing:
#    1904     with self._idle_draw_cntx():
# -> 1905         self.draw(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\backends\backend_agg.py:387, in FigureCanvasAgg.draw(self)
#     384 # Acquire a lock on the shared font cache.
#     385 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     386       else nullcontext()):
# --> 387     self.figure.draw(self.renderer)
#     388     # A GUI class may be need to update a window using this draw, so
#     389     # don't forget to call the superclass.
#     390     super().draw()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\figure.py:3162, in Figure.draw(self, renderer)
#    3159             # ValueError can occur when resizing a window.
#    3161     self.patch.draw(renderer)
# -> 3162     mimage._draw_list_compositing_images(
#    3163         renderer, self, artists, self.suppressComposite)
#    3165     renderer.close_group('figure')
#    3166 finally:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~\anaconda3\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:3137, in _AxesBase.draw(self, renderer)
#    3134 if artists_rasterized:
#    3135     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3137 mimage._draw_list_compositing_images(
#    3138     renderer, self, artists, self.figure.suppressComposite)
#    3140 renderer.close_group('axes')
#    3141 self.stale = False
#
# File ~\anaconda3\Lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~\anaconda3\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\collections.py:1005, in _CollectionWithSizes.draw(self, renderer)
#    1002 @artist.allow_rasterization
#    1003 def draw(self, renderer):
#    1004     self.set_sizes(self._sizes, self.figure.dpi)
# -> 1005     super().draw(renderer)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\collections.py:411, in Collection.draw(self, renderer)
#     409     gc.set_antialiased(self._antialiaseds[0])
#     410     gc.set_url(self._urls[0])
# --> 411     renderer.draw_markers(
#     412         gc, paths[0], combined_transform.frozen(),
#     413         mpath.Path(offsets), offset_trf, tuple(facecolors[0]))
#     414 else:
#     415     if self._gapcolor is not None:
#     416         # First draw paths within the gaps.
#
# TypeError: must be real number, not str

# %% [markdown]
# #### Gradient Descent vs Cost Functions
#
# - In machine learning, cost functions measure how well a model's predictions match the actual data, while gradient descent is an algorithm used to (Quickly come up with the cost function/regression line) minimize the cost function by iteratively adjusting the model's parameters.
# - Essentially, the cost function quantifies the error, and gradient descent finds the best parameter settings to reduce that error.
# - Here's a more detailed breakdown:
# -
# - Cost Functions:
# - Purpose:
# - Cost functions (also known as loss functions) are mathematical expressions that quantify the difference between predicted values from a machine learning model and the actual values in the training data.
# - Evaluation:
# - They output a single value (the "cost" or "loss") that represents the model's error. A higher cost indicates a larger discrepancy between predictions and actual values.
# - Examples:
# - Common cost functions include Mean Squared Error (MSE) for regression and Cross-Entropy for classification.
# - .
# - Gradient Descent:
# - Purpose:
# - Gradient descent is an optimization algorithm that aims to find the minimum value of a function, in this case, the cost function.
# - Process:
# - It works by iteratively adjusting the model's parameters (e.g., weights in a neural network) in the direction of the negative gradient (steepest descent) of the cost function.

# %% [markdown]
# #### Note:-
# - Linear Regression uses Ordinary Least Squares (OLS) method to estimate the parameters in a linear regression model.
# - Logistic regression, neural networks, support vector machines, and even boosting algorithms like XGBoost uses Gradient Descent.
