# %% [markdown]
# ### Cost Functions - Find the best fit lines for given training data set.
# - Mean Absolute Error - MAE - (Sum of |Actual Value - Predicted Value|)/N >>> (Sum of |Actual Value - (mx + b)|)/N
# - <b>Mean Square Error - MSE</b> - (Square of Actual Value - Predicted Value)/N >>> (Square of (Actual Value - (mx + b)))/N
# - Root Mean Square Error - RMSE - Sq Root(Square of Actual Value - Predicted Value)/N) >>> Sq Root((Square of (Actual Value - (mx + b)))/N)
# - All these are used in Linear Regression only

# %% [markdown]
# #### Mean Absolute Error - MAE
#
# ![image.png](attachment:b3dd2a7e-dad3-4776-81a9-9f00252a0fab.png)

# %% [markdown]
# #### Mean Square Error - MSE - Most popular
# - Delats shown in below diagram is (Actual Value - Predicted Value)
# - Predicted Value:- y = mx + b
# - N = Number of data points
# - .
# - Deltas shown in below diagram
#
# ![image.png](attachment:cc511aa2-fbd2-49bf-a148-8aea72b83863.png)
#
# - Delta Replaced with Formula
# ![image.png](attachment:dd1ac1a2-dbcf-460c-8173-ee5581b6812e.png)
#
# - Predicted Value Replaced with Formula
#
# ![image.png](attachment:eec9469a-e5f4-4479-ae37-68d7cff3d614.png)

# %% [raw]
# - This method is good, but takes more iterations, gradient descent might be better compared to this.

# %% [markdown]
# #### Root Mean Square Error - RMSE
#
# ![image.png](attachment:ccd598ae-88a9-41a3-adf8-879402e542ff.png)
