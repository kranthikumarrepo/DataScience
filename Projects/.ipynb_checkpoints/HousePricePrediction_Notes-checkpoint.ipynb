# %% [raw]
# 1. There are 81 columns i.e. 80 features and 1 output column
# 2. Output is numeric - regression output.
# 3. Out of 81 columns there are 43 non numerical and 38 numerical
# 4. Since there are non numerical features, we need to perform encoding.
# 5. Since there are numerical features, we might need to performm scaling.
# 6. There are 1460 records
# 7. Can ignore ID column - this is an identifier
# 8. There are features with nulls. Requires NULLs to be imputed with mean/mode depending on the datatype.
# 9.
#
# General observations:-
# 1. Handle NULLs - Impute - There are 5 features (Alley, MasVnrType, PoolQC, Fence, MiscFeature) where 50% of the data is null, we can ignore these features while fitting the data. Check the limit should be 50% or 40% (Extra feature FireplaceQu has 40% nulls).
#     TrainDF_HousingData.drop(['Alley'],axis=1,inplace=True), so on...
# 3. Encoding is required - Need to check if there are both Ordinal(Ordinal encoding) and nominal features(One hot encoding).
# 4. Scaling of numerical data is required.
# 5. Feature wise analysis & action to be taken
#    1. MSSubClass
#        Values range - from 20 to 190
#        Duplicates - yes, its common to have dups in this feature. No special action is required.
#        Scaling/ Encoding - Might require scaling
#        NULLs - Does not exist
#        Outliers - No outliers, but there are 6 records with very high Sale price - TrainDF_HousingData.query('MSSubClass == 60 and SalePrice > 500000') - ID = 692, 770, 804, 1047, 1170, 1183 >>> Delete???
#
#    2. MSZoning
#        Values range - RL(Most values - 80%), RM, etc.
#        Duplicates - yes, its common to have dups in this column. No special action is required.
#        Scaling/ Encoding - Nominal data, requies One hot Encoding
#        NULLs - Does not exist, if exists, then fill the nulls with the mode. TrainDF_HousingData['MSZoning'] = TrainDF_HousingData['MSZoning'].fillna(TrainDF_HousingData['MSZoning'].mode()[0])
#        Outliers - No outliers, but there are 2 records with very high sale price - TrainDF_HousingData.query('MSZoning == "RL" and SalePrice > 700000') ID = 692, 1183
#
#    3. LotFrontage
#        Values range - from 21 feet to 313 feet
#        Duplicates - yes, its common to have dups in this feature. No special action is required.
#        Scaling/ Encoding - Might require scaling
#        NULLs - 259 nulls, it could mean there are properties that are not connected to the street. Fill with mean value? TrainDF_HousingData['LotFrontage'] = TrainDF_HousingData['LotFrontage'].fillna(TrainDF_HousingData['LotFrontage'].mean())
#        Outliers - There are 2 outliers, ID = 935 and 1299 - TrainDF_HousingData.query('LotFrontage > 190') >>> Delete???
#
#    4. BsmtCond
#         Values range - TA(80% of records), Gd, Fa, Po
#         Duplicates - yes, but as expected.
#         Scaling/ Encoding - Ordinal data, requies OrdinalEncoding.
#         NULLs - 37 nulls, Replace with mode. TrainDF_HousingData['BsmtCond'] = TrainDF_HousingData['BsmtCond'].fillna(TrainDF_HousingData['BsmtCond'].mode()[0])
#         Outliers - NA
#
#    5. BsmtQual
#         Values range - TA(600+ records), Gd(600+ records), Fa, Ex
#         Duplicates - yes, but as expected
#         Scaling/ Encoding - Ordinal data, requies OrdinalEncoding.
#         NULLs - 37 nulls, Replace with mode. TrainDF_HousingData['BsmtCond'] = TrainDF_HousingData['BsmtCond'].fillna(TrainDF_HousingData['BsmtCond'].mode()[0])
#         Outliers - NA
#
#    6. LotArea
#         Values range - between 1,300 sft to 2,15,245 sft
#         Duplicates - NA
#         Scaling/ Encoding - Numerical, Might require scaling
#         NULLs - No
#         Outliers - Yes, Extreme outliers - ID = 250, 314, 336, 707. Also check if we need to drop outliers with manual calculation - TrainDF_HousingData.query('LotArea > 40460.62287932922')
#
#    7. FireplaceQu
#         Values range - Gd(380), TA(313), Fa
#         Duplicates - NA
#         Scaling/ Encoding - Ordinal data, requies OrdinalEncoding.
#         NULLs - 690, should we ignore this feature or fill with mode?
#         Outliers - NA
#
#     8. GarageType
#         Values range - Attchd(870), Detchd(387), etc...
#         Duplicates - NA
#         Scaling/ Encoding - Nominal, requires one hot encoding
#         NULLs - 81, impute with mode
#         Outliers - NA
#
#     9. GarageYrBlt
#         Values range - 1900 to 2010
#         Duplicates - NA
#         Scaling/ Encoding - Yes, scaling is required
#         NULLs - 81, fill with mean?
#         Outliers - NA, may be 1900 - ID = 94
#
#     10. GarageFinish
#         Values range - Unf(605), Rnf(422), Fin(352)
#         Duplicates - NA
#         Scaling/ Encoding - Encoding, OneHotEncoding
#         NULLs - 81, mode impute
#         Outliers - NA
#
#     11. GarageQual
#         Values range - TA(1300+), Fa(48),..
#         Duplicates - NA
#         Scaling/ Encoding - Encoding, OrdinalEncoding
#         NULLs - 81, mode impute
#         Outliers - NA
#
#     12. GarageCond
#         Values range - TA(1300+), Fa(48),..
#         Duplicates - NA
#         Scaling/ Encoding - Encoding, OrdinalEncoding
#         NULLs - 81, mode impute
#         Outliers - NA
#
#     13. MasVnrArea
#         Values range - 0 to 1600
#         Duplicates - NA
#         Scaling/ Encoding - Scaling
#         NULLs - 8, mean impute
#         Outliers - ID = 298, Seem to be outliers, 32 records with manual TrainDF_HousingData.query('MasVnrArea > 646.8838814696435')
#
#     14. BsmtExposure
#         Values range - No(953), Av(221),..
#         Duplicates - NA
#         Scaling/ Encoding - Encoding, OrdinalEncoding or OneHot?
#         NULLs - 38, mode impute
#         Outliers - NA
#
#     15. BsmtFinType1
#         Values range - Unf(430), Rec(54),
#         Duplicates - NA
#         Scaling/ Encoding - Encoding, OrdinalEncoding or OneHot?
#         NULLs - 37, mode impute
#         Outliers - NA
#
#     16. BsmtFinType2
#         Values range - Unf(1256), Rec(54),
#         Duplicates - NA
#         Scaling/ Encoding - Encoding, OrdinalEncoding or OneHot?
#         NULLs - 38, mode impute
#         Outliers - NA
#
#     17. Utilities
#         Values range - AllPub(1459), NoSeWa(1)
#         Duplicates - NA
#         Scaling/ Encoding - Encoding, OneHot
#         NULLs - No
#         Outliers - NA
#
#     18. Exterior1st
#         Values range - multiple types
#         Duplicates - NA
#         Scaling/ Encoding - Encoding, OneHot
#         NULLs - No
#         Outliers - NA
#
#     19. Exterior2nd
#         Values range - multiple types
#         Duplicates - NA
#         Scaling/ Encoding - Encoding, OneHot
#         NULLs - No
#         Outliers - NA
#
#     20. BsmtFinSF1
#         Values range - 0 to 5644 sqft
#         Duplicates - NA
#         Scaling/ Encoding - Scaling
#         NULLs - No
#         Outliers - yes, ID = 1299, TrainDF_HousingData.query('BsmtFinSF1 > 3000')
#
#     21. BsmtFinSF2
#         Values range - 0 to 1474 sqft
#         Duplicates - NA
#         Scaling/ Encoding - Scaling
#         NULLs - No
#         Outliers - yes, ID = 441, TrainDF_HousingData.query('BsmtFinSF2 > 400 and SalePrice > 500000')
#
#     22. BsmtUnfSF
#         Values range - 0 to 2336 sqft
#         Duplicates - NA
#         Scaling/ Encoding - Scaling
#         NULLs - No
#         Outliers - No
#
#     23. TotalBsmtSF
#         Values range - 0 to 6110 sqft
#         Duplicates - NA
#         Scaling/ Encoding - Scaling
#         NULLs - No
#         Outliers - yes, Id= 1299 - TrainDF_HousingData.query('TotalBsmtSF > 3500')
#
#     24. BsmtFullBath
#         Values range - 0 to 3
#         Duplicates - NA
#         Scaling/ Encoding - Scaling
#         NULLs - No
#         Outliers - yes, Id= 739 - TrainDF_HousingData.query('BsmtFullBath == 3')
#
#     25. BsmtHalfBath
#         Values range - 0 to 2
#         Duplicates - NA
#         Scaling/ Encoding - Scaling
#         NULLs - No
#         Outliers - yes, Id= 598, 955 - TrainDF_HousingData.query('BsmtHalfBath == 2')
#
#     26. KitchenQual
#         Values range - Ta(735), Gd(586), etc.
#         Duplicates - NA
#         Scaling/ Encoding - Ordinal Encoding
#         NULLs - No
#         Outliers - No
#
#     27. Functional
#         Values range - Typ(1360), ...
#         Duplicates - NA
#         Scaling/ Encoding - OneHotEncoding
#         NULLs - No
#         Outliers - No-May be
#
#     28. GarageCars
#         Values range - 2(824),1(369) ...
#         Duplicates - NA
#         Scaling/ Encoding - Scaling
#         NULLs - No
#         Outliers - No-May be
#
#     29. GarageArea
#         Values range - 0 to 1418
#         Duplicates - NA
#         Scaling/ Encoding - Scaling
#         NULLs - No
#         Outliers - No-May be >>>GarageArea ID = 1062
#
#     30. SaleType
#         Values range - WD(1267), New(122), etc.
#         Duplicates - NA
#         Scaling/ Encoding - OneHotEncoding
#         NULLs - No
#         Outliers - No-May be
#
#     31. OverallQual
#         Values range - Very Excellent(5 - 397), Excellent(4 - 374), ...
#         Duplicates - NA
#         Scaling/ Encoding - Scaling?
#         NULLs - No
#         Outliers - May be - TrainDF_HousingData.query('OverallQual == 10 and SalePrice < 200000')
#
#     32. OverallCond
#         Values range - Very Excellent(5 - 821), Excellent(4 - 252), ...
#         Duplicates - NA
#         Scaling/ Encoding - Scaling?
#         NULLs - No
#         Outliers - yes, ID = 379, 692, 1183 -
#                 TrainDF_HousingData.query('OverallCond == 2 and SalePrice > 300000')
#                 TrainDF_HousingData.query('OverallCond == 5 and SalePrice > 700000')
#                 TrainDF_HousingData.query('OverallCond == 6 and SalePrice > 700000')
#
#     33. YearBuilt
#         Values range - 1872-2010
#         Duplicates - NA
#         Scaling/ Encoding - Scaling
#         NULLs - No
#         Outliers - Yes, ID = 186, TrainDF_HousingData.query('YearBuilt < 1900 and SalePrice > 400000')
#
#     34. YearRemodAdd
#         Values range - 1950-2010
#         Duplicates - NA
#         Scaling/ Encoding - Scaling
#         NULLs - No
#         Outliers - No
#
#     35. 1stFlrSF
#         Values range - 334-4692
#         Duplicates - NA
#         Scaling/ Encoding - Scaling
#         NULLs - No
#         Outliers - No
#
#     36. 2ndFlrSF
#         Values range - 0-2695
#         Duplicates - NA
#         Scaling/ Encoding - Scaling
#         NULLs - No
#         Outliers - No
#
# ColumnName - Deatiled Pending from Feature LowQualFinSF
#     Values range -
#     Duplicates -
#     Scaling/ Encoding -
#     NULLs -
#     Outliers -
#
# Questions:-
# 1. FireplaceQu - 40% of records have nulls - 690 - should we ignore this feature or fill with mode?
# 2. BsmtExposure - Good, Avg, Min, No exposure, No basement(NULLs) - treat it as Ordinal or Nominal for encoding?
# 3. BsmtFinType1 & BsmtFinType2 - Good, Avg, Below Avg, Low Quality, No basement, Unfinished
# 4. Utilities - Since there is only one value in 99.99% cases, do we need to use this feature?

# %%
### Pipelines

# Nulls - Impute with mean/ mode
mean - LotFrontage, GarageYrBlt, MasVnrArea
TrainDF_HousingData['LotFrontage'] = TrainDF_HousingData['LotFrontage'].fillna(TrainDF_HousingData['LotFrontage'].mean())
TrainDF_HousingData['GarageYrBlt'] = TrainDF_HousingData['GarageYrBlt'].fillna(TrainDF_HousingData['GarageYrBlt'].mean())
TrainDF_HousingData['MasVnrArea'] = TrainDF_HousingData['MasVnrArea'].fillna(TrainDF_HousingData['MasVnrArea'].mean())

mode - BsmtCond, BsmtQual, FireplaceQu (Impute or ignore feature as 40% are nulls?), GarageType, GarageFinish, GarageQual, GarageCond, 
BsmtExposure,BsmtFinType1, BsmtFinType2
TrainDF_HousingData['BsmtCond'] = TrainDF_HousingData['BsmtCond'].fillna(TrainDF_HousingData['BsmtCond'].mode()[0])
TrainDF_HousingData['BsmtQual'] = TrainDF_HousingData['BsmtQual'].fillna(TrainDF_HousingData['BsmtQual'].mode()[0])
TrainDF_HousingData['FireplaceQu'] = TrainDF_HousingData['FireplaceQu'].fillna(TrainDF_HousingData['FireplaceQu'].mode()[0])
TrainDF_HousingData['GarageType'] = TrainDF_HousingData['GarageType'].fillna(TrainDF_HousingData['GarageType'].mode()[0])
TrainDF_HousingData['GarageFinish'] = TrainDF_HousingData['GarageFinish'].fillna(TrainDF_HousingData['GarageFinish'].mode()[0])
TrainDF_HousingData['GarageQual'] = TrainDF_HousingData['GarageQual'].fillna(TrainDF_HousingData['GarageQual'].mode()[0])
TrainDF_HousingData['GarageCond'] = TrainDF_HousingData['GarageCond'].fillna(TrainDF_HousingData['GarageCond'].mode()[0])
TrainDF_HousingData['BsmtExposure'] = TrainDF_HousingData['BsmtExposure'].fillna(TrainDF_HousingData['BsmtExposure'].mode()[0])
TrainDF_HousingData['BsmtFinType1'] = TrainDF_HousingData['BsmtFinType1'].fillna(TrainDF_HousingData['BsmtFinType1'].mode()[0])
TrainDF_HousingData['BsmtFinType2'] = TrainDF_HousingData['BsmtFinType2'].fillna(TrainDF_HousingData['BsmtFinType2'].mode()[0])

# To drop the records where there are nulls
TrainDF_HousingData.dropna(inplace=True)

# To check if there are still nulls after imputing
sns.heatmap(TrainDF_HousingData.isnull(),yticklabels=False,cbar=False,cmap='coolwarm')

# Drop
NULLs - Alley, MasVnrType, PoolQC, Fence, MiscFeature >>> 50% data is null
TrainDF_HousingData.drop(['Alley', 'MasVnrType', 'PoolQC', 'Fence', 'MiscFeature'],axis=1,inplace = True)

Drop - ID - unique identifier, no significance
TrainDF_HousingData.drop(['Id'],axis=1,inplace = True)

# Outliers - Drop
Outlier_Values = [49,  186,  198,  250,  298,  314,  336, 441,  496,  524,  598, 636,  636,  707,  739,  810,  935,  955, 1062, 1299]
TrainDF_HousingData = TrainDF_HousingData[TrainDF_HousingData.Id.isin(Outlier_Values) == False]

Additional - [ 379, 598, 692, 1183 ]

BsmtFinSF1 - ID = 1299
BsmtFinSF2 - ID = 441
LotFrontage - ID = 935 and 1299
TotalBsmtSF - ID = 1299
BsmtFullBath - ID - 739
BsmtHalfBath - Id= 598, 955
LotArea - ID = 250, 314, 336, 707. Also check if we need to drop outliers with manual calculation - Housing_Data_All_Master.query('LotArea > 40460.62287932922')
GarageYrBlt - NA
GarageArea ID = 1062
MasVnrArea - ID = 298, and there seems to be 32 records with manual Housing_Data_All_Master.query('MasVnrArea > 646.8838814696435')
OverallQual - Id = 524(may be), 1299 - TrainDF_HousingData.query('OverallQual == 10 and SalePrice < 200000')
LowQualFinSF - Id=186 - TrainDF_HousingData.query('LowQualFinSF > 500 and SalePrice > 400000')
GrLivArea - id = 524, 1299 - TrainDF_HousingData.query('GrLivArea > 4000 and SalePrice < 300000')
BedroomAbvGr - ID = 636 - TrainDF_HousingData.query('BedroomAbvGr == 8')
KitchenAbvGr - ID = 955, 49, 810 - TrainDF_HousingData.query('KitchenAbvGr == 3/2')
TotRmsAbvGrd - ID = 636 - TrainDF_HousingData.query('TotRmsAbvGrd == 14')
OpenPorchSF - ID = 496 - TrainDF_HousingData.query('OpenPorchSF > 500 and SalePrice < 100000')
EnclosedPorch - ID = 198, TrainDF_HousingData.query('EnclosedPorch > 500')
MiscVal

# Scaling
MSSubClass, LotFrontage, LotArea, GarageYrBlt, MasVnrArea, BsmtFinSF1, BsmtFinSF2, BsmtUnfSF, BsmtFullBath, GarageCars, GarageArea, 
YearBuilt, YearRemodAdd, 1stFlrSF, 2ndFlrSF
OverallQual???, 
OverallCond - ID = 379, 692, 1183
YearBuilt ID = 186

# Encoding
OneHotEncoding - MSZoning, GarageType, GarageFinish, Utilities(Not yet finalized), Exterior1st, Exterior2nd, Functional, SaleType
OrdinalEncoding - BsmtCond, BsmtQual, FireplaceQu, GarageQual, GarageCond, KitchenQual
BsmtExposure/ BsmtFinType1 / BsmtFinType2 - Ordinal or Nominal?
# Out:
#   Cell In[22], line 8
#     mode - BsmtCond, BsmtQual, FireplaceQu (Impute or ignore feature as 40% are nulls?), GarageType, GarageFinish, GarageQual, GarageCond
#                                             ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
sum(Housing_Data_All_Master.MSSubClass.isnull()) >>> isnull count

sorted(Housing_Data_All_Master.MSSubClass.unique()) >>> unnique values in sorted
Housing_Data_All_Master.MSZoning.value_counts() >>> unnique values in sorted for categorical column 

plt.scatter(x = 'MSSubClass', y = 'SalePrice', data = Housing_Data_All_Master) >>> Scatterplot
Housing_Data_All_Master.query('MSSubClass == 60 and SalePrice > 500000') >>> Queries
plt.boxplot(Housing_Data.LotArea) >>> Box plot

'Street',
       'Alley', 'LotShape', 'LandContour', '', 'LotConfig',
       'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
       'HouseStyle', ,
       'RoofStyle', 'RoofMatl', '', '', ', 'ExterQual', 'ExterCond', 'Foundation', '',
       '', '', '', ' 'Heating',
       'HeatingQC', 'CentralAir', 'Electrical', '',
       '', '', '',
       '', '', '', '',
       '', 'PavedDrive', , '',
       'SaleCondition', 'SalePrice'

# %%
# Import the required libraries

import pandas as pd
import numpy as np
from scipy import stats
from sklearn.metrics import mean_squared_error

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.compose import make_column_transformer, ColumnTransformer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder, StandardScaler, OneHotEncoder

from sklearn.linear_model import LinearRegression, Ridge
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, VotingRegressor, StackingRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
import lightgbm as lgb

# %%
# Read the input housing dataset
# https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/data

Housing_Data_All_Master = pd.read_csv(r"C:\Users\ACER\Desktop\Kranthi\DataScience_Desktop\Projects\DataMites_Projects\PRCP-1020-HousePricePred\data.csv")

Housing_Data_All_Master.head(2)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
#
# [2 rows x 81 columns]

# %%
# Create a heatmap to visualize the nulls in the features

sns.heatmap(Housing_Data_All_Master.isnull(),yticklabels=True,cbar=False)
# Out:
# <Axes: >

# %%
Housing_Data_All_Master['MSZoning'].mode()[0]
# Out:
# 'RL'

# %%
Housing_Data_All_Master_Copy = Housing_Data_All_Master.copy()

# %%
sns.heatmap(Housing_Data_All_Master_Copy.isnull(),yticklabels=False,cbar=False,cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.heatmap(Housing_Data_All_Master_Copy.isnull(),yticklabels=False,cbar=False,cmap='coolwarm')
# Out:
# <Axes: >

# %%
sum(Housing_Data_All_Master_Copy.BsmtFinType1.isnull())
# Out:
# 37

# %%
sum(Housing_Data_All_Master_Copy.BsmtQual.isnull())
# Out:
# 0

# %%
Housing_Data_All_Master_Copy['BsmtFinType1'] = Housing_Data_All_Master_Copy['BsmtFinType1'].fillna(Housing_Data_All_Master_Copy['BsmtFinType1'].mode()[0])

# %%
Housing_Data_All_Master_Copy.dropna(inplace=True)

# %%
Housing_Data_All_Master_Copy.shape
# Out:
# (1412, 75)

# %%
Housing_Data_All_Master_Copy['GarageYrBlt'].mean()[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 Housing_Data_All_Master_Copy['GarageYrBlt'].mean()[0]
#
# IndexError: invalid index to scalar variable.

# %%
sns.heatmap(Housing_Data_All_Master_Copy.isnull(),yticklabels=False,cbar=False,cmap='coolwarm')
# Out:
# <Axes: >

# %%
Housing_Data_All_Master_Copy['LotFrontage'] = Housing_Data_All_Master_Copy['LotFrontage'].fillna(Housing_Data_All_Master_Copy['LotFrontage'].mean())
Housing_Data_All_Master_Copy['GarageYrBlt'] = Housing_Data_All_Master_Copy['GarageYrBlt'].fillna(Housing_Data_All_Master_Copy['GarageYrBlt'].mean())

Housing_Data_All_Master_Copy['BsmtCond'] = Housing_Data_All_Master_Copy['BsmtCond'].fillna(Housing_Data_All_Master_Copy['BsmtCond'].mode()[0])
Housing_Data_All_Master_Copy['BsmtQual'] = Housing_Data_All_Master_Copy['BsmtQual'].fillna(Housing_Data_All_Master_Copy['BsmtQual'].mode()[0])
Housing_Data_All_Master_Copy['FireplaceQu'] = Housing_Data_All_Master_Copy['FireplaceQu'].fillna(Housing_Data_All_Master_Copy['FireplaceQu'].mode()[0])
Housing_Data_All_Master_Copy['GarageType'] = Housing_Data_All_Master_Copy['GarageType'].fillna(Housing_Data_All_Master_Copy['GarageType'].mode()[0])
Housing_Data_All_Master_Copy['GarageFinish'] = Housing_Data_All_Master_Copy['GarageFinish'].fillna(Housing_Data_All_Master_Copy['GarageFinish'].mode()[0])
Housing_Data_All_Master_Copy['GarageQual'] = Housing_Data_All_Master_Copy['GarageQual'].fillna(Housing_Data_All_Master_Copy['GarageQual'].mode()[0])
Housing_Data_All_Master_Copy['GarageCond'] = Housing_Data_All_Master_Copy['GarageCond'].fillna(Housing_Data_All_Master_Copy['GarageCond'].mode()[0])

# %%
Housing_Data_All_Master_Copy.dropna(inplace=True)

Housing_Data_All_Master_Copy.drop(['Alley', 'MasVnrType', 'PoolQC', 'Fence', 'MiscFeature'],axis=1,inplace = True)
Housing_Data_All_Master_Copy.drop(['Id'],axis=1,inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 3
#       1 Housing_Data_All_Master_Copy.dropna(inplace=True)
# ----> 3 Housing_Data_All_Master_Copy.drop(['Alley', 'MasVnrType', 'PoolQC', 'Fence', 'MiscFeature'],axis=1,inplace = True)
#       4 Housing_Data_All_Master_Copy.drop(['Id'],axis=1,inplace = True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['Alley', 'MasVnrType', 'PoolQC', 'Fence', 'MiscFeature'] not found in axis"

# %%
import numpy as np
Outlier_Values = np.sort(Outlier_Values)

# %%
Outlier_Values
# Out:
# array([  49,  186,  198,  250,  298,  314,  336,  441,  496,  524,  598,
#         636,  636,  707,  739,  810,  935,  955,  955, 1062, 1299])
