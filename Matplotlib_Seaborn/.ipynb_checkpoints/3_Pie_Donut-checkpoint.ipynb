# %% [markdown]
# ### Pie Chart - Donut Chart
# - are used to visually represent the proportional distribution of a whole into different categories.
# - They are particularly useful for showing how each part contributes to the total, making it easy to compare the size of different slices and understand their relative proportions.

# %% [markdown]
# ### Pending
# - pie with seaborn
# - donut with matplotlib and seaborn
# - Also update in 0_AllGraphTypes_Syntax once all are done.

# %% [markdown]
# ### Pie Chart Using Matplotlib

# %%
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

Company = ['Google','Amazon','Facebook','Microsoft']
Revenue = [90,136,89,27]

plt.title("Revenue percentage")
plt.pie(Revenue,labels=Company,
        explode = [0,0.08,0,0],
        #colors=['r','b','g','y'],
        shadow = True,
        radius = 0.8,
        startangle = 280,
        autopct='%0.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x19527c65790>,
# ...
#  [Text(0.7410966973790806, -0.47452680128083347, 'Google'),
#   Text(0.061686944269728414, 0.9580160337419535, 'Amazon'),
#   Text(-0.7992505612104988, -0.3682370709267374, 'Facebook'),
#   Text(-0.06461084216328505, -0.8776248851730171, 'Microsoft')],
#  [Text(0.4042345622067711, -0.2588328006986364, '26.32%'),
#   Text(0.03598405082400824, 0.5588426863494728, '39.77%'),
#   Text(-0.43595485156936287, -0.20085658414185673, '26.02%'),
#   Text(-0.03524227754361002, -0.47870448282164557, '7.89%')])
