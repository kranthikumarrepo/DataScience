# %% [raw]
# ann, cnn, rnn, lstm

# %% [raw]
# Single layer perceptron
#
# Sigmoid function:- f(z) = 1/(1+e power -z) >>> Values btw 0 and 1
# z = w1xi1 + w2xi2 + .. + b
#
# Activation function - ex: Sigmoid fn.

# %% [raw]
# Multi layer perceptron

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, accuracy_score

# %%
# Load IRIS Dataset

X,y = load_iris(return_X_y=True)
# Data = load_iris(return_X_y=False)
# X = Data.data
# y = Data.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
# Scaling

StandardScaler_Obj = StandardScaler()
StandardScaler_Obj.fit(X_train)
X_train_Transformed = StandardScaler_Obj.transform(X_train)
X_test_Transformed = StandardScaler_Obj.transform(X_test)
print("Train shape ", X_train_Transformed.shape, " Test Shape ",X_test_Transformed.shape)
# Out:
# Train shape  (120, 4)  Test Shape  (30, 4)

# %%
from sklearn.neural_network import MLPClassifier

MLPClassifier_Obj_S = MLPClassifier()
MLPClassifier_Obj_S.fit(X_train_Transformed,y_train)

MLPClassifier_Obj_NS = MLPClassifier()
MLPClassifier_Obj_NS.fit(X_train,y_train)
# Out:
# C:\Users\ACER\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\ACER\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier()

# %%
y_Pred_S = MLPClassifier_Obj.predict(X_test_Transformed)
y_Pred_NS = MLPClassifier_Obj.predict(X_test)

# %%
accuracy_score(y_Pred_S,y_test)
# Out:
# 0.9333333333333333

# %%
accuracy_score(y_Pred_NS,y_test)
# Out:
# 0.26666666666666666

# %%
print(classification_report(y_Pred_S,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96        13
#            1       0.88      0.88      0.88         8
#            2       1.00      0.89      0.94         9
#
#     accuracy                           0.93        30
#    macro avg       0.93      0.92      0.93        30
# weighted avg       0.94      0.93      0.93        30

# %%
#print(classification_report(y_Pred_NS,y_test))

# %%
from sklearn.linear_model import LogisticRegression

LogisticRegression_Obj_NS = LogisticRegression()
LogisticRegression_Obj_NS.fit(X_train,y_train)

LogisticRegression_Obj_S = LogisticRegression()
LogisticRegression_Obj_S.fit(X_train_Transformed,y_train)
# Out:
# LogisticRegression()

# %%
y_Pred_LR_NS = LogisticRegression_Obj_NS.predict(X_test)

y_Pred_LR_S = LogisticRegression_Obj_S.predict(X_test_Transformed)

# %%
accuracy_score(y_Pred_LR,y_test)
# Out:
# 0.9666666666666667

# %%
accuracy_score(y_Pred_LR_S,y_test)
# Out:
# 0.9666666666666667

# %%
# Single layer Perceptron

from sklearn.linear_model import Perceptron

Perceptron_Obj_NS = Perceptron(max_iter=1000,eta0=1.0,random_state=42)
Perceptron_Obj_S = Perceptron(max_iter=1000,eta0=1.0,random_state=42)

# %%
Perceptron_Obj_NS.fit(X_train,y_train)
Perceptron_Obj_S.fit(X_train_Transformed,y_train)
# Out:
# Perceptron(random_state=42)

# %%
y_Predict_Per_NS = perceptron_clf.predict(X_test)
y_Predict_Per_S = perceptron_clf.predict(X_test_Transformed)
accuracy_score(y_Predict_Per_S,y_test)
# Out:
# 0.6666666666666666

# %%
accuracy_score(y_Predict_Per_NS,y_test)
# Out:
# 0.7666666666666667

# %% [markdown]
# https://playground.tensorflow.org/#activation=tanh&batchSize=10&dataset=spiral&regDataset=reg-plane&learningRate=0.03&regularizationRate=0&noise=0&networkShape=4,3,3,2&seed=0.87840&showTestData=false&discretize=false&percTrainData=50&x=true&y=true&xTimesY=false&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=classification&initZero=false&hideText=false

# %%
## Multi Layer Perceptron

from sklearn.
